# %% [markdown]
# ![Redis](https://redis.io/wp-content/uploads/2024/04/Logotype.svg?auto=webp&quality=85,75&width=120)
# # Evaluating search techniques
#
# ## Let's Begin!
# <a href="https://colab.research.google.com/github/redis-developer/redis-ai-resources/blob/main/python-recipes/vector-search/04_search_benchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install Packages

# %%
# %pip install -q "redisvl>=0.4.1" sentence-transformers pandas "redis>=5.2.0" beir bm25s elasticsearch

# %% [markdown]
# ### Data/Index Preparation

# %%
# load beir dataset
from beir import util
from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval.evaluation import EvaluateRetrieval

# link for dataset: https://sites.google.com/view/fiqa/
dataset = "fiqa"
url = f"https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{dataset}.zip"

out_dir = "./beir_datasets"
data_path = util.download_and_unzip(url, out_dir)

corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")
# Out:
# /Users/robert.shelton/.pyenv/versions/3.11.9/lib/python3.11/site-packages/beir/util.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/57638 [00:00<?, ?it/s]

# %%
# corpus ex
corpus["3"]
# Out:
# {'text': "I'm not saying I don't like the idea of on-the-job training too, but you can't expect the company to do that. Training workers is not their job - they're building software. Perhaps educational systems in the U.S. (or their students) should worry a little about getting marketable skills in exchange for their massive investment in education, rather than getting out with thousands in student debt and then complaining that they aren't qualified to do anything.",
#  'title': ''}

# %%
# query ex
queries["8"]
# Out:
# 'How to deposit a cheque issued to an associate in my business into my business account?'

# %%
# qrel ex
qrels['8']
# Out:
# {'566392': 1, '65404': 1}

# %% [markdown]
# ### Install Redis Stack
#
# Later in this tutorial, Redis will be used to store, index, and query vector
# embeddings and full text fields. **We need to have a Redis
# instance available.**
#
# #### Local Redis
# Use the shell script below to download, extract, and install [Redis Stack](https://redis.io/docs/getting-started/install-stack/) directly from the Redis package archive.

# %%
# NBVAL_SKIP
# %%sh
curl -fsSL https://packages.redis.io/gpg | sudo gpg --dearmor -o /usr/share/keyrings/redis-archive-keyring.gpg
echo "deb [signed-by=/usr/share/keyrings/redis-archive-keyring.gpg] https://packages.redis.io/deb $(lsb_release -cs) main" | sudo tee /etc/apt/sources.list.d/redis.list
sudo apt-get update  > /dev/null 2>&1
sudo apt-get install redis-stack-server  > /dev/null 2>&1
redis-stack-server --daemonize yes

# %% [markdown]
# #### Alternative Redis Access (Cloud, Docker, other)
# There are many ways to get the necessary redis-stack instance running
# 1. On cloud, deploy a [FREE instance of Redis in the cloud](https://redis.com/try-free/). Or, if you have your
# own version of Redis Enterprise running, that works too!
# 2. Per OS, [see the docs](https://redis.io/docs/latest/operate/oss_and_stack/install/install-stack/)
# 3. With docker: `docker run -d --name redis-stack-server -p 6379:6379 redis/redis-stack-server:latest`

# %% [markdown]
# ### Define the Redis Connection URL
#
# By default this notebook connects to the local instance of Redis Stack. **If you have your own Redis Enterprise instance** - replace REDIS_PASSWORD, REDIS_HOST and REDIS_PORT values with your own.

# %%
import os
import warnings

warnings.filterwarnings('ignore')

# Replace values below with your own if using Redis Cloud instance
REDIS_HOST = os.getenv("REDIS_HOST", "localhost") # ex: "redis-18374.c253.us-central1-1.gce.cloud.redislabs.com"
REDIS_PORT = os.getenv("REDIS_PORT", "6379")      # ex: 18374
REDIS_PASSWORD = os.getenv("REDIS_PASSWORD", "")  # ex: "1TNxTEdYRDgIDKM2gDfasupCADXXXX"

# If SSL is enabled on the endpoint, use rediss:// as the URL prefix
REDIS_URL = f"redis://:{REDIS_PASSWORD}@{REDIS_HOST}:{REDIS_PORT}"

# %% [markdown]
# ### Load corpus data into Redis for evaluation
#
# #### format/vectorize corpus data for search index

# %%
from redisvl.utils.vectorize import HFTextVectorizer

# load model for embedding our movie descriptions
emb_model = HFTextVectorizer('sentence-transformers/all-MiniLM-L6-v2')

# %%
corpus_data = []

# this can take a minute
for key in corpus:
    text = corpus[key]["title"] + " " + corpus[key]["text"]
    corpus_data.append(
        {
            "_id": key,
            "text": text,
            "title": corpus[key]["title"],
            "vector": emb_model.embed(text, as_buffer=True)
        })

# %%
# corpus_data ex
corpus_data[0]
# Out:
# {'_id': '3',
#  'text': " I'm not saying I don't like the idea of on-the-job training too, but you can't expect the company to do that. Training workers is not their job - they're building software. Perhaps educational systems in the U.S. (or their students) should worry a little about getting marketable skills in exchange for their massive investment in education, rather than getting out with thousands in student debt and then complaining that they aren't qualified to do anything.",
#  'title': '',
#  'vector': b'\xef),\xbd\xc6\xae-\xbcTj\xc5;\x8e$\x8f=\x81na=\x9b\xf1\x15=\x9cD\xed;\x8f\x83\x84\xbc\xe5Mz\xbdJd;\xbd(?\xcf<\x06i\xdb=%T\xa0\xbc\x94s\xed:\xa9[\x8a\xbd\xb4>,\xbd\xf2~U=\x923\x83\xbd\xb7\x1b\x98=k\x8cJ\xbd\xde\xab\xd8\xbcZ$\xe6;\x95\xa4\x80=\xe6\xb3\x8d=N\xaa];\xe4\xdf\x01<\xbc\xbb\x13\xbb\xa8\xa1\x9a\xbd\x7f\x0e\x8c\xbcK\xf8\xb5\xbcN\x11\x1f\xbc\x03\x02\x16<+\x8b\x12<\xafw\x9d<J\x89.=)l\x8f= \x99-<s\x06\xb8=5\xbb\xde\xbc\x86\xd8\xd5\xbc\xd1\xbe\x1b:\xfa.\xec\xbc3v\x9d\xbc\x7fS4\xbc\xb2\x84o<\x13\x9e\x88\xbd\xef~J\xbb=\x89\x01\xbe\x9b\x8dI\xbd\xc9\xc5\x0e=\xf5i\x88\xbd\x92\x11\x86\xbdl;\x90=,Ww\xbd:\xab\x9a\xbdP\x84\x0f<\xa8\xab\xad<\xdfZd<[\t7\xbd\xa6\x93\x11=\xeb\xdaO\xbd\x84{\xf6\xbc\xa0h`:\x8a\xa21\xbc\xd3\xa2\xdd\xbc\xfb\xc7[\xbd\xcad9\xbd\x82\xe59=\xee\xf1V\xbc_\xc1?\xbd\xb74\xc1<x\x01\xdf<\xb3J\xd3;=\xbd(=\x14\x88\x8b=\x01\x9d\x01=\xf8#n\xbc\xae\xd8X=3XE=\x9d"\xc0\xbc\x9f\xa2;=O\xadl\xbd2\x8a\x1b=\x03\xd2\xdf\xbc\x87@\x98\xbd\xc3\xa3\x89;E\x81<\xbcB\xf0\x00\xbc\xab\xc2\xa2=D\x0b\xcf\xbc;8\xc4\xbb~L\x07\xbd-\xedP\xbd\x9eB\xcd;\x81\xf4\n\xbd\xe7F\xc3;\xac+x="H\xe6=\xfe\xba\xad\xbco\xd3\x85\xbc\xc5\r\xe1<%L\xb6<H\xbe/\xbd\x1c\xd6Y\xbbQ$\xc7\xbdd\x19\\=,U\x9c\xbc\xe4\t\x97\xbd\xb5\x91\x9f=P\xc9\xba\xbc\x98mB=\xf9\x9de=\xbdCL\xbd\xf5\xdf\xf5\xbb\xc1\xd0\x1a\xbd\x93\x8a\xa2=\xc0\xd8\x18\xbdq\xc8\xa5;H]\xc3\xbd\x9f\xdf\x06>\x1b\xa6Q\xbb\xe6H@\xbb\x87Z\xc1\xbd\x95\x99\xd0\xbc\xe8 \x08\xbc\xb0\xbc\x01\xbeIq\xbe\xbdr9f\x08\x1f@\x92=r3?=\x885\xa3<\x99\x83\xe5\xbc\x05\xec\xb7\xbc\xc0\xf5\xc8\xbd/>O=\xc8n\xdb=\x1ey\xcc<\xeb\xa3,<\xe4\xc9\xff\xbcT\xa1\xff;\xbaJ\x85=\x11\xd2\x87=f\xab\xa0=\xcc\x95\x9e\xbb\x9e-\x9a\xbd\x1fa>\xbd\x8b\xf5!=\xc0\x1b\xe6<\xfd\x87\xa0=\xd6\xfa)\xbd\x1f\xc8\n\xbd\x01\xfc\xab\xbc%\xb8\x99\xbc)K$\xbc\xca\xfd\xe5;Ag]=\xc2\x88\xb7=\x06\x19F<?\x1d6=\xdd\xa7!\xbc\xa8\xef\xbd\xbc<V\x97;\xfc\xd5-<\xe6\xcb\xc09\x0e\xb6\x03\xbd\xf3}\x9a=\x07\x9bW=l\xf0\x13=8\x0e\xa6<\xff\xd4\x10\xbbSu4=\xae\xe0\xcd\xbaac8=\x80Bd<\xb4\xe3\xa6=\xceo4\xbd\xfdE\xe8\xbc\x19\x83\x87=\xbd-N\xbd\xb1h\xcd;\xf8*\x83<\xf41\x91\xbd\xbf\xbe\xbe\xbb\xb0\xe2\xfa=\xb3\xdf\xd6\xbc\xec_>=\xa2\xaf\xfb\xbc\x18\xb6\x8f<\xac6\x04\xbdj<\x17\xbdk\x8a%;\xc5\xf6\xec<\x8b\x18q\xbd\x8e\xceb\xbc4\xbe\x97=oL,<\xf3nH=\x8da\n\xbd~\xd9\x83\xbc\xff\xc3\xd0\xbc\x99!\xba\xbd\xb5Fd\xbd\xaf\xe9\xde;\xbc\xcc-\xbd.\xf2\xfa<)\x89\xb8<\xc3\xa6\x1a=\xf5\xc7\x82\xbc*\x96\xa1=\xabH\xe7\xbc\xbf\x06\xa7=\xa49G\xbd5\r\xd8=\xb4\xdac:\x152\x8a<\xa6\xc4\x0f\xbc\xb5xY=e\xd0\xd7=\x97\xef"=\xda\xf1\t\xbd\x94\xbf\x8d\xbd\x8b\xad\x9e=|\xf8\x1d=/4\xfa\x88\xb9B\xd1;f\xe3/=\xc0n\x9b\xbd\x91\xc9>\xbc\x9b\xf9\xfc<a\x97\x83=\x88\xa2\xa3=\x17\x97i=a\x81\xf0\xbd\xd7\xc4\xbe<\xe2VJ\xba2\x98\xed\xbcP"\xa1\xbd\x1c\x1d\xdd<g\xaf\xa5\xbd\xf7TS\xbdQ\x0c\x98\xbd\xe2\xa3\x86=h\x83z\xbc&\xcc\xc9<7D\xfc<\xa0\x8c\xc4<G\xa9-<\t4q=n\xdd\xd0<\x99y\xec<H#\xbd\xbd\xea\xa0\x14=\x1f\xcb5=\xae"\xa7==<g<\xe4\xb8\x8a;\xa3\xfc\xb7<?\x17|<\x90QQ\xbd0\xcc><\x07F\x12\xbd\xeb\xa8\xed<R\xec\xb9\xbc\xe7\xb2\x11>\xc3i.;\xd1\xb0\x9a\xbdl\xb9*\xbe\xdbg\x95\xbdq6Q\xbc\xact\x15\xbd\xac\x9as<\xca\n\x87\xbdC]\x18;\xb4\xea\xd9\xbb\xfd#\xe8;\xe4\xca\x94\xba\x11\xd4\xaa\xbc\x8e\x8f2\xbc\x1c4\xab<\xc7\xa3\xe4\xbc\xba\x8d\xc6<\'\xd1\x07\xbd\x10\nv\xbd\xf2\x08\x8a\xb9\x89\x9c\xa4=|\xb1\xbb\xbcl\x8a?=\xe9\x0c|\xbcE\xb6\x1d=\xb3Q\x8e\xbdC\xb0\xd2<]\xcd\xa0=l:\x91\xbd\xb4\xac\xe7<\x11\x19\x1a=Z\xcd\xcd<\xa8\x88\xe9;\x08 \xf5\xbaJ]\x14\xbd\xc7A1=\x88]\x8f\xbcw\x95\x9c\xbb D\xe4\xbd\xaf\x8b\xbc\xbcl\xcf\xe1<\xb3E\xb9\xbdw\rp=\xf2\\\x06=\x1a$\x87=\xdf\t\xa5=\xf0>\x9f<\xc4\xbb\xba<B\xef?\xbd-4|\xbd\x02\xc5\x1a\xbdG\xd1\xf3\xbb\x83\xd1\xad<\xf6\x88\xa8<7\xa0\x87<\x08\xea_\xb3\x05K\x92\xbc\xc0\xa4\x92\xbd\x16^\x80\xbb\x8d\x90\x86\xbaX\xf6?\xbc3!v\xbd`\xbfQ\xbdxe6<\xbb\xf1\x14=\x95\xda\xb5=\x87\xa8d\xbd\x97\x14\xc3\xbcS\x16\xe3;a%\xe8\xbcx\xab\xa4=\xd6\xe1\x1a>Eh\x10\xbdy<\xb7<@<!\xbd\x9d\x0bG=\x86,\xb3=v\x18\xf5:\x906\x15\xbd\x08\xdf\n=\x87\xef\x06=\x95\x85\r\xbc=;v\xbd\xf0\xfe+=\x14\x9d1=}\x1f\xa4<e\xfeS\xbd\xb8\x04\x8b\xbd\x07\xf2 ...

# %% [markdown]
# ### Define Redis index schema
#
# Below, we build a schema that represents our movie objects.

# %%
from redisvl.schema import IndexSchema
from redisvl.index import SearchIndex


schema = IndexSchema.from_dict({
  "index": {
    "name": dataset,
    "prefix": dataset,
    "storage": "hash"
  },
  "fields": [
    { "name": "_id", "type": "tag" },
    { "name": "text", "type": "text" },
    { "name": "title", "type": "text" },
    {
        "name": "vector",
        "type": "vector",
        "attrs": {
            "dims": 384,
            "distance_metric": "cosine",
            "algorithm": "hnsw",
            "datatype": "float32"
        }
    }
  ]
})


index = SearchIndex(schema, redis_url=REDIS_URL)
index.create(overwrite=False, drop=False)
# Out:
# 09:29:43 redisvl.index.index INFO   Index already exists, not overwriting.

# %% [markdown]
# ### Populate index
#
# Load corpus objects into Redis

# %%
index.load(corpus_data)
# Out:
# ['fiqa:01JPQE6GXN3P7X3YERF0WG3N01',
#  'fiqa:01JPQE6GXNR77Q93NTH20JTMD1',
#  'fiqa:01JPQE6GXN09N0P0675TPD9W0Q',
#  'fiqa:01JPQE6GXN7MNCJGP6BXR5YEEA',
#  'fiqa:01JPQE6GXN5AC7D0FNVDTT5S11',
#  'fiqa:01JPQE6GXNT9M3RJK4K42DZZ5W',
#  'fiqa:01JPQE6GXNKD8TXWBPXAXGZ9JM',
#  'fiqa:01JPQE6GXNPQ085A6G65WRTPBJ',
#  'fiqa:01JPQE6GXNX2QZAFVSQSAZSAWC',
#  'fiqa:01JPQE6GXND8726J3W663H2815',
#  'fiqa:01JPQE6GXN8MYRDMT7EGA7AWNF',
#  'fiqa:01JPQE6GXND2WHST0QFB7G52H3',
#  'fiqa:01JPQE6GXNNSMCCYGWSWJ1EHFY',
#  'fiqa:01JPQE6GXNG4WNDK1C20GGKZCB',
#  'fiqa:01JPQE6GXNBJ3ZMF89VT8RZ9FT',
#  'fiqa:01JPQE6GXNTPH33B9E9Z9TT6QS',
#  'fiqa:01JPQE6GXNF04KBKJ60ZRW25BP',
#  'fiqa:01JPQE6GXN01F5M3EZQ5F8HNM3',
#  'fiqa:01JPQE6GXND0SCK50RJMTA7ZQT',
#  'fiqa:01JPQE6GXN3XENMJWJSVC51GTX',
#  'fiqa:01JPQE6GXNBZDYQ3YY05ZQRTZS',
#  'fiqa:01JPQE6GXNAJS034GCP0BWXJC5',
#  'fiqa:01JPQE6GXNW9NW7211EPY9ZRRR',
#  'fiqa:01JPQE6GXPQSJTP1E41BCKHDS8',
#  'fiqa:01JPQE6GXPPJCPMX0T3JST32X2',
#  'fiqa:01JPQE6GXP9MFZ1B8VYXSNGEY1',
#  'fiqa:01JPQE6GXPQYJN4ST00GVWG0WP',
#  'fiqa:01JPQE6GXPD5FM202XZ9A6NRWR',
#  'fiqa:01JPQE6GXPGC2ZSDWTQR9GGHP6',
#  'fiqa:01JPQE6GXPGVGBPV1J3BGAY97D',
#  'fiqa:01JPQE6GXPAETCJ6YDGHE4MVJB',
#  'fiqa:01JPQE6GXP91RCR82N8G1SP28R',
#  'fiqa:01JPQE6GXPWYPHM4RMZKGPXZ4B',
#  'fiqa:01JPQE6GXP7C9CCZJ4MYXW9VB6',
#  'fiqa:01JPQE6GXP5E67E6QAMX7KQF6X',
#  'fiqa:01JPQE6GXP6823MTP95PH9VS4W',
#  'fiqa:01JPQE6GXPYTT5QPBJ5G2AJ6F9',
#  'fiqa:01JPQE6GXP1T7A46QNKA18G0GB',
#  'fiqa:01JPQE6GXP8M4JA3V4D7PPKZFP',
#  'fiqa:01JPQE6GXPZZCER2HKPP8PBQ8Q',
#  'fiqa:01JPQE6GXP6FMF1S999DC9TSTB',
#  'fiqa:01JPQE6GXPEBSPT4HK7C17Q6BS',
#  'fiqa:01JPQE6GXP75RHVJYQZRTT2PC7',
#  'fiqa:01JPQE6GXPXMX0WV59KGH95RB7',
#  'fiqa:01JPQE6GXP272ADG53VX2WXW9J',
#  'fiqa:01JPQE6GXP6Z7XSV2P2ZJPGDMJ',
#  'fiqa:01JPQE6GXP5DDDRRC0N1JVDY0Q',
#  'fiqa:01JPQE6GXPJ3KRY5H89K6NBCHB',
#  'fiqa:01JPQE6GXPEC28FAREGXMGAZ90',
#  'fiqa:01JPQE6GXPWQG881RTMMPR5HRQ',
#  'fiqa:01JPQE6GXPAY7XZXV5AJF75SP0',
#  'fiqa:01JPQE6GXP8MRRZYVTDHVDS3X6',
#  'fiqa:01JPQE6GXPVMSJY829HC3RE8PT',
#  'fiqa:01JPQE6GXP03HZN7PBMFSDR7VN',
#  'fiqa:01JPQE6GXPSCNB6VZJ8092NNZF',
#  'fiqa:01JPQE6GXPQZ02CW6NP6V1DX5Z',
#  'fiqa:01JPQE6GXPQ5PSN9P8PMT31P0E',
#  'fiqa:01JPQE6GXPJYJYXQ86KRXA57SV',
#  'fiqa:01JPQE6GXPGHDYGV0C68E33BPB',
#  'fiqa:01JPQE6GXPAE0GSHNNYB7R38TM',
#  'fiqa:01JPQE6GXPYSDR08QYT5Q11JT0',
#  'fiqa:01JPQE6GXPQ3WVC93ZACXDHJR6',
#  'fiqa:01JPQE6GXPCMJ9SENA1Y35B7D6',
#  'fiqa:01JPQE6GXPKEQ3YQ5M0PRRHMVM',
#  'fiqa:01JPQE6GXPNC1FBB2WYGXYVPWW',
#  'fiqa:01JPQE6GXPW36ENQX6GT800DBK',
#  'fiqa:01JPQE6GXP5WFYB35DD6D7DJSE',
#  'fiqa:01JPQE6GXPGPKGBPC583SS5DHW',
#  'fiqa:01JPQE6GXPAEZB4J7G4R32NNDW',
#  'fiqa:01JPQE6GXPXXEB7Q4EDC3YBSJP',
#  'fiqa:01JPQE6GXPYSSA0XDWKGV8YM7C',
#  'fiqa:01JPQE6GXPE3YTH96KCPJ2WWJV',
#  'fiqa:01JPQE6GXPB2H3N91KT0HEC91K',
#  'fiqa:01JPQE6GXPEBCB0A4NG46ZMD8W',
#  'fiqa:01JPQE6GXPVG968ZHJ0XJ57YTD',
#  'fiqa:01JPQE6GXPKXPAZFEAB8A7QZ2Z',
#  'fiqa:01JPQE6GXPZ0CX944PR7J2YJ6Z',
#  'fiqa:01JPQE6GXP8DMF3YM65BNKDTBB',
#  'fiqa:01JPQE6GXP31TRSDTYEYTW3HGP',
#  'fiqa:01JPQE6GXPH85SMQ4M42TN6A9X',
#  'fiqa:01JPQE6GXP1NGANV9TQ0X2215G',
#  'fiqa:01JPQE6GXP6JFM7T3BY2WA9RDB',
#  'fiqa:01JPQE6GXP12Y9TGHHCGNJKYXW',
#  'fiqa:01JPQE6GXP2Y9P4A6D3TS3SQFH',
#  'fiqa:01JPQE6GXPB54ZJG1HBPSXR493',
#  'fiqa:01JPQE6GXP69P74DFMCYQ21S3Y',
#  'fiqa:01JPQE6GXPKEV5DB0X8WEX980B',
#  'fiqa:01JPQE6GXPXR10AAAYBBJ257HK',
#  'fiqa:01JPQE6GXPVKXNZKG4CRVS2K21',
#  'fiqa:01JPQE6GXPPM14P73AWF9CT6H2',
#  'fiqa:01JPQE6GXPSEYXVTD0XXFMAA66',
#  'fiqa:01JPQE6GXPP59NQJPYG3PQWT79',
#  'fiqa:01JPQE6GXPVTR951CG5QCQF9QE',
#  'fiqa:01JPQE6GXP24S8XVXPPBJ0T2WQ',
#  'fiqa:01JPQE6GXPK3EC724Y5TTB0WEZ',
#  'fiqa:01JPQE6GXPXEFKZ4WA0ZN2G611',
#  'fiqa:01JPQE6GXPJD8YP0SW0J7CDB1F',
#  'fiqa:01JPQE6GXPKS5K8RYG4593SEF2',
#  'fiqa:01JPQE6GXPY8JWNAC2AM8V4QBK',
#  'fiqa:01JPQE6GXP4PYWFG5DB8T297H8',
#  'fiqa:01JPQE6GXPNKN01Z1H9KB90BA3',
#  'fiqa:01JPQE6GXQ0ET4Y2PF5DV8M0KH',
#  'fiqa:01JPQE6GXQNA2JR8N98GWXCRK3',
#  'fiqa:01JPQE6GXQ5FPVGN60HJDWF2TM',
#  'fiqa:01JPQE6GXQP0C0CTQCZTY348V3',
#  'fiqa:01JPQE6GXQCAVW3WXVGCSNEF1X',
#  'fiqa:01JPQE6GXQQNDY0BYE52599J4P',
#  'fiqa:01JPQE6GXQZY16P83WXG30573X',
#  'fiqa:01JPQE6GXQ38QPT69GFDS2EWDC',
#  'fiqa:01JPQE6GXQE3BVKDDP1SZXB4VD',
#  'fiqa:01JPQE6GXQXPJ2Z2RTC07CHPB8',
#  'fiqa:01JPQE6GXQ73RGQ9KMHAJFD05G',
#  'fiqa:01JPQE6GXQ8TWK8R1GKFBKYGAS',
#  'fiqa:01JPQE6GXQ6ZK17WYP5ZMKYWTQ',
#  'fiqa:01JPQE6GXQ5P6QD0JT06GT19MJ',
#  'fiqa:01JPQE6GXQF86VF8CBBKJ12N0W',
#  'fiqa:01JPQE6GXQ82F1D0B3JTZMJJ89',
#  'fiqa:01JPQE6GXQV2P9YEEZP9GCZT1N',
#  'fiqa:01JPQE6GXQQW2WPY2MED6WT4RH',
#  'fiqa:01JPQE6GXQFJJGQDY64GPPWH44',
#  'fiqa:01JPQE6GXQK94266ETF8XR7S2N',
#  'fiqa:01JPQE6GXQT1S0EHATFPWGXQ5Y',
#  'fiqa:01JPQE6GXQVV3MH8SQ9YRRRSM6',
#  'fiqa:01JPQE6GXQY50V9523WDANTZAH',
#  'fiqa:01JPQE6GXQ6DSXPA104TJQ42CB',
#  'fiqa:01JPQE6GXQJMJAXQF93FRM3AYZ',
#  'fiqa:01JPQE6GXQC2KB5WT1J0B8EXQN',
#  'fiqa:01JPQE6GXQSX0MXJCWAHE4Y673',
#  'fiqa:01JPQE6GXQZP99M2ZVKPDY9G9Q',
#  'fiqa:01JPQE6GXQARJ6YPQCVG4E0CYC',
#  'fiqa:01JPQE6GXQF37J977QPK845BYA',
#  'fiqa:01JPQE6GXQBRQPPMQBYSSRJ2F0',
#  'fiqa:01JPQE6GXQYJBQP0Q85XDD2XKA',
#  'fiqa:01JPQE6GXQV36QNJ00FTFNG998',
#  'fiqa:01JPQE6GXQ7YDJAK6WP9V7MZC8',
#  'fiqa:01JPQE6GXQXWSXWQ1Z66RQ96JM',
#  'fiqa:01JPQE6GXQ2W7ATWZZD252JKAZ',
#  'fiqa:01JPQE6GXQS3PQE7JH22Q5A1TZ',
#  'fiqa:01JPQE6GXQ55RBRMG4JZB0QJT7',
#  'fiqa:01JPQE6GXQ05AQ0Z73FXFNWJJG',
#  'fiqa:01JPQE6GXQ8QJ5TP6036V6DDQF',
#  'fiqa:01JPQE6GXQA4Y6H6YWXJYSZNVD',
#  'fiqa:01JPQE6GXQHR8XPBG5EHVXVEY2',
#  'fiqa:01JPQE6GXQENDB4G9BYJ0S27EK',
#  'fiqa:01JPQE6GXQBZKRNART1CTM5C7E',
#  'fiqa:01JPQE6GXQ0GJQ57HBDN9AGQA9',
#  'fiqa:01JPQE6GXQ53CAKFBJWMMTBB9P',
#  'fiqa:01JPQE6GXQ6YJXE1FJSSVNFKAB',
#  'fiqa:01JPQE6GXQ3XEAPMG6HS6NZWRH',
#  'fiqa:01JPQE6GXQHE1ZED5XFRZQATTS',
#  'fiqa:01JPQE6GXQD4JPE761KYFRB43B',
#  'fiqa:01JPQE6GXQR8XTBE48W4PYKZDQ',
#  'fiqa:01JPQE6GXQZ8KSV5FHDZMB13CN',
#  'fiqa:01JPQE6GXQ0J81BF1H1N7H7F6K',
#  'fiqa:01JPQE6GXQ2Y2DH3TB62QSA936',
#  'fiqa:01JPQE6GXQ5BJZ6Y6WMC1NJ444',
#  'fiqa:01JPQE6GXQE49QVDR93D25BDSP',
#  'fiqa:01JPQE6GXQREQCC3KEYZDECE0F',
#  'fiqa:01JPQE6GXQ6JDP0RPBRGG6YSN7',
#  'fiqa:01JPQE6GXQ0NFD7SAQ6Z5YHE5F',
#  'fiqa:01JPQE6GXQQ57CZ9WBVVQ6VS97',
#  'fiqa:01JPQE6GXQSP2FS8XPCWS91RBT',
#  'fiqa:01JPQE6GXQP1QYSWZEAD58C76V',
#  'fiqa:01JPQE6GXQCXKMQ8NYXBYZG874',
#  'fiqa:01JPQE6GXQ174QGGQFPF22T47W',
#  'fiqa:01JPQE6GXQKT29QWK1RDAZHNQ0',
#  'fiqa:01JPQE6GXQTG9N9KBKT1MWGT4C',
#  'fiqa:01JPQE6GXQEZCYX6P100C99NVM',
#  'fiqa:01JPQE6GXQMD0003NGCMHS2915',
#  'fiqa:01JPQE6GXQDB92948TJSV2P1EP',
#  'fiqa:01JPQE6GXQKB2MAV51AD8N8KR1',
#  'fiqa:01JPQE6GXQVF7MW6744Y276FRD',
#  'fiqa:01JPQE6GXQM89AHGMP52SKZWQ9',
#  'fiqa:01JPQE6GXQYRNMS4RRN60WRT6T',
#  'fiqa:01JPQE6GXQVGKVKDKEBF6T9V3E',
#  'fiqa:01JPQE6GXQ2063HZB5PC4N99AJ',
#  'fiqa:01JPQE6GXQ3X8XX5JP3FNQ6CVR',
#  'fiqa:01JPQE6GXQKHN2K4NKCHWJ98EQ',
#  'fiqa:01JPQE6GXQXY07B2MB4XDM0MEG',
#  'fiqa:01JPQE6GXQYHVVWE0T4QA04P2M',
#  'fiqa:01JPQE6GXQK7KVK96SAQ5P8FZ2',
#  'fiqa:01JPQE6GXQ4NJ741W6196K16NW',
#  'fiqa:01JPQE6GXQJMXVHGWSGAWQW7ZC',
#  'fiqa:01JPQE6GXQCS9HDXPCMZH97YDV',
#  'fiqa:01JPQE6GXQZS3CFQ6GZYHKP4J1',
#  'fiqa:01JPQE6GXQ73MWH09RR45KRGVC',
#  'fiqa:01JPQE6GXQAV6YTZPPBSKKRHPC',
#  'fiqa:01JPQE6GXQZYHCZZYRR8FGSM85',
#  'fiqa:01JPQE6GXQ5EG0C05CKARM4250',
#  'fiqa:01JPQE6GXQNNVSAF9K2CE9WV0B',
#  'fiqa:01JPQE6GXQ5XWHQQ40ENWPTBSD',
#  'fiqa:01JPQE6GXQWMR5B05NRXTZ0Z75',
#  'fiqa:01JPQE6GXQ9C2K5YWMD8D7GFYG',
#  'fiqa:01JPQE6GXQ1GTXXCHB0GSDDY4M',
#  'fiqa:01JPQE6GXQRBDPJ6ZPJET5HS6J',
#  'fiqa:01JPQE6GXQGRBJ028E5ZAB6K0C',
#  'fiqa:01JPQE6GXQD2F3DP48AVCXJ091',
#  'fiqa:01JPQE6GXQ9PHWJJDGVA5FM72P',
#  'fiqa:01JPQE6GXQN8KBRJTXH11Q82AE',
#  'fiqa:01JPQE6GXQDWE92PMY4MZZX7WM',
#  'fiqa:01JPQE6H00EGQW02CMDMF377B5',
#  'fiqa:01JPQE6H00VPG0P5E66E3AKVHT',
#  'fiqa:01JPQE6H00Q5H8RB6Y5E3GTKHN',
#  'fiqa:01JPQE6H00YT2ZSTVQJ1175RKT',
#  'fiqa:01JPQE6H00QKZR3AJ25591B3J0',
#  'fiqa:01JPQE6H00VZ6KG0N9M96V57FA',
#  'fiqa:01JPQE6H00Q5YWWF5R5PJ2SDTG',
#  'fiqa:01JPQE6H008VJ76BEPZW2JQSWV',
#  'fiqa:01JPQE6H00MT433A5PKW5CHDRN',
#  'fiqa:01JPQE6H00VTCCWWAE6RQ6WW2B',
#  'fiqa:01JPQE6H00CJEC94FRB4P6HGK7',
#  'fiqa:01JPQE6H00K12SR18PWBK293TM',
#  'fiqa:01JPQE6H00QZR1AM3G5HM9TJ1C',
#  'fiqa:01JPQE6H00XR2SXFQ0YW4BY04Z',
#  'fiqa:01JPQE6H00DVTKZ7CKXARYHPSM',
#  'fiqa:01JPQE6H00DMJQ1YRPWSJSSDHM',
#  'fiqa:01JPQE6H00QP24XWZZG3WFA3MT',
#  'fiqa:01JPQE6H00GEQHZY6STB1D9Q0P',
#  'fiqa:01JPQE6H00RHFY348HEBW9F7WC',
#  'fiqa:01JPQE6H00Z0SH4EXW43DDRQPW',
#  'fiqa:01JPQE6H001JEXVQB0JD04DY5R',
#  'fiqa:01JPQE6H00G3PBWA1EH13ZXR19',
#  'fiqa:01JPQE6H00PVX3XGHZV0CDKGDF',
#  'fiqa:01JPQE6H00CWRS5WA3XC135M3T',
#  'fiqa:01JPQE6H00AZTW96F6734YM77Y',
#  'fiqa:01JPQE6H00TAT1YF5ZS95S3A2S',
#  'fiqa:01JPQE6H00NBJQZ1PDTWPW7ETG',
#  'fiqa:01JPQE6H00HW00NHDHSQRQTJDA',
#  'fiqa:01JPQE6H00AJ066WBCG87MEHNZ',
#  'fiqa:01JPQE6H00GXQ547PG069ZPAKF',
#  'fiqa:01JPQE6H00JG8DSS9ZZ08BJ3QT',
#  'fiqa:01JPQE6H00Y88FNJPT45NN89EH',
#  'fiqa:01JPQE6H002KR7PD88S883N0S2',
#  'fiqa:01JPQE6H0024AWZTJ87AXDSDRJ',
#  'fiqa:01JPQE6H009FA3P36M1DA3QVHE',
#  'fiqa:01JPQE6H01ER4J8R97A3JWEC6Z',
#  'fiqa:01JPQE6H01RS7NDPQB6WCYSG60',
#  'fiqa:01JPQE6H010V07R9Y1E23M5QAA',
#  'fiqa:01JPQE6H01HT62CEX4J4JHXR18',
#  'fiqa:01JPQE6H0173373DTN9X4JRXVV',
#  'fiqa:01JPQE6H01D92G2A7F3EMSJWKS',
#  'fiqa:01JPQE6H018WTWM59JC1R009ZR',
#  'fiqa:01JPQE6H010B0KF440BKA4DECE',
#  'fiqa:01JPQE6H01W03FV6JZPDGYG9AT',
#  'fiqa:01JPQE6H01N55GKTCS4GCKADAE',
#  'fiqa:01JPQE6H01EBHX28H9F615RA9S',
#  'fiqa:01JPQE6H01XGR0DEZPPT4DFZEX',
#  'fiqa:01JPQE6H01X2WZDMB5B7F3PDM8',
#  'fiqa:01JPQE6H01RG1T55DC7YBM4N64',
#  'fiqa:01JPQE6H0199E8R4W43A6PYMRY',
#  'fiqa:01JPQE6H01Q4J5X9T70G3ZS559',
#  'fiqa:01JPQE6H01KD0X3K93MRS396N7',
#  'fiqa:01JPQE6H01Z3B07TDRC6XG7HMZ',
#  'fiqa:01JPQE6H013W6MDD6MR1B3F0FS',
#  'fiqa:01JPQE6H012ZF89GZP056K1CT6',
#  'fiqa:01JPQE6H014MPK2JPYARX4BG6P',
#  'fiqa:01JPQE6H019NXMNWBCS4X1T607',
#  'fiqa:01JPQE6H01C55D93VKDBQVHSGJ',
#  'fiqa:01JPQE6H014RWKZ9HS65T6208C',
#  'fiqa:01JPQE6H01VPGXMSA63QTKF91D',
#  'fiqa:01JPQE6H0120RDQMCFJPVRN4SB',
#  'fiqa:01JPQE6H0144QRZZP1CEEDC5NY',
#  'fiqa:01JPQE6H01VJNKN4XKZ0TSMRC6',
#  'fiqa:01JPQE6H01GEYZK3AMPATBBCC7',
#  'fiqa:01JPQE6H018EQQMGR186G22YJ6',
#  'fiqa:01JPQE6H01BQ71K9DY72K76H9E',
#  'fiqa:01JPQE6H01VD29BCXPWJF35Z7D',
#  'fiqa:01JPQE6H013JCH206XZ1XGRY38',
#  'fiqa:01JPQE6H01FPP84Q2PFSS7QERE',
#  'fiqa:01JPQE6H01ACJT9MNRBW37248N',
#  'fiqa:01JPQE6H019DDVCK156R7RK817',
#  'fiqa:01JPQE6H01DXSKE0TVZ6W0TM4Y',
#  'fiqa:01JPQE6H01KX4CSJV43A2WQSRJ',
#  'fiqa:01JPQE6H01787430S4EHANJXDP',
#  'fiqa:01JPQE6H01EKZBC7WJSPBWWEBH',
#  'fiqa:01JPQE6H01RH7XGSC7FZPAMTV3',
#  'fiqa:01JPQE6H015PYBQGX6MG465ZGR',
#  'fiqa:01JPQE6H01DFSYSQS7064N31ZX',
#  'fiqa:01JPQE6H016TFYC0PPSS1MQ0D3',
#  'fiqa:01JPQE6H01E3YDSE2JSA093103',
#  'fiqa:01JPQE6H01RRRE5ZHGEA65YSEC',
#  'fiqa:01JPQE6H01R4ZDK3P055BQ2WC1',
#  'fiqa:01JPQE6H01HBBST3RQ6GE181Y3',
#  'fiqa:01JPQE6H01VN8YGTCBBPC1PBQJ',
#  'fiqa:01JPQE6H018C1YH5DRK4HD3ZE1',
#  'fiqa:01JPQE6H0174KMVBBZG5D1EV53',
#  'fiqa:01JPQE6H01W2Z9P26BW9HT15XN',
#  'fiqa:01JPQE6H01BYRVFZF0363QWF26',
#  'fiqa:01JPQE6H017TW86EGQ7K9C6GBC',
#  'fiqa:01JPQE6H01H25W4QR9572P25CA',
#  'fiqa:01JPQE6H016F3974CRVGSSJPK7',
#  'fiqa:01JPQE6H0114B47MTCTYCZWB11',
#  'fiqa:01JPQE6H01971VCAKJH9BYCSMT',
#  'fiqa:01JPQE6H01J8P7DT9ESX8R0XQF',
#  'fiqa:01JPQE6H01ATJWYE97768KTYP0',
#  'fiqa:01JPQE6H01SMJMFTQ60WMEYXHQ',
#  'fiqa:01JPQE6H01V4APX0WHKVERG8B7',
#  'fiqa:01JPQE6H01A4AT7W93RZSZ080W',
#  'fiqa:01JPQE6H01Q1RGVZTZPWSCBF2R',
#  'fiqa:01JPQE6H0129WJ0M6XG5N8HMTP',
#  'fiqa:01JPQE6H01B2WDDGJC5B0N8AW1',
#  'fiqa:01JPQE6H01VX5TNWYCBGESQTHJ',
#  'fiqa:01JPQE6H01S3HVXZSWKJM4PPQD',
#  'fiqa:01JPQE6H01N27PWB8SSF6TG9MS',
#  'fiqa:01JPQE6H013S77F6S9XSQQHFA3',
#  'fiqa:01JPQE6H013J040JTF0Y0282T0',
#  'fiqa:01JPQE6H01VM459N3AAV0B2H4H',
#  'fiqa:01JPQE6H01AVER18JT872KAGV8',
#  'fiqa:01JPQE6H017BC7CFZPWFNJ35TC',
#  'fiqa:01JPQE6H01V7CDM1182GGQY04J',
#  'fiqa:01JPQE6H01GXSKAE46DK3N1BW2',
#  'fiqa:01JPQE6H01YZ7G79QE8EGAMGGC',
#  'fiqa:01JPQE6H01WZM33ARC3W3C860P',
#  'fiqa:01JPQE6H019T3MY75DK23SC4DY',
#  'fiqa:01JPQE6H015ARJT4XB7JXC3D68',
#  'fiqa:01JPQE6H01467ZD9KSMMSZ2XWQ',
#  'fiqa:01JPQE6H0188GXNR9VAC3ST56C',
#  'fiqa:01JPQE6H01GMFM4MBMQ22MSQWY',
#  'fiqa:01JPQE6H01F4ZMGPF3TWRNVDJX',
#  'fiqa:01JPQE6H010XNWTETCQWKWB09E',
#  'fiqa:01JPQE6H01V3XBHWAF4JJRQEHF',
#  'fiqa:01JPQE6H01EF005PW0HTW1G6E6',
#  'fiqa:01JPQE6H012E46JJAM0J6R78NB',
#  'fiqa:01JPQE6H015JTSEHYH6NZ46NGG',
#  'fiqa:01JPQE6H01CKDW7MWXQ0HBMKDW',
#  'fiqa:01JPQE6H018GJQACSCDEKCKV70',
#  'fiqa:01JPQE6H015D977FE8ERJA07Q1',
#  'fiqa:01JPQE6H0125HHCTA7X4NSCQBD',
#  'fiqa:01JPQE6H01QT6W4KB653875N8F',
#  'fiqa:01JPQE6H01WME6P23A92NFTY9E',
#  'fiqa:01JPQE6H01W0N2J7QD8FJ7MCH6',
#  'fiqa:01JPQE6H0134SD9K4CTTE41QTF',
#  'fiqa:01JPQE6H01SC2J246GE9Q8XW5C',
#  'fiqa:01JPQE6H016ZDQZYQ0XCJWWDW6',
#  'fiqa:01JPQE6H01NHQFNCHX7DE60NQW',
#  'fiqa:01JPQE6H01HCR70M8G6B6PHWJZ',
#  'fiqa:01JPQE6H01APPGPBJ8GCXXXK3V',
#  'fiqa:01JPQE6H01GFE8M8C6JCKF0SHZ',
#  'fiqa:01JPQE6H019GQQD760SNR18B90',
#  'fiqa:01JPQE6H014VX3MJPB1N1A6KFG',
#  'fiqa:01JPQE6H01DAFDENFMX93GXRC3',
#  'fiqa:01JPQE6H019CDH9CB827H2MZHW',
#  'fiqa:01JPQE6H01DB5GSQ74FTK4WV2B',
#  'fiqa:01JPQE6H01G62YA2B27ZYE8N78',
#  'fiqa:01JPQE6H01SN70YHEBA7CRMRJJ',
#  'fiqa:01JPQE6H017FSWZKDC0W6SWJY6',
#  'fiqa:01JPQE6H01039EF8C95W1YR8VK',
#  'fiqa:01JPQE6H01S7RAKKHYGXHYGQ1T',
#  'fiqa:01JPQE6H01SG9EPWJCJZ7CKZF0',
#  'fiqa:01JPQE6H01972SQAQTTDCXAVJD',
#  'fiqa:01JPQE6H01HN2KYKBEKDGVMCS0',
#  'fiqa:01JPQE6H01GZWZCP11CQE8X6PV',
#  'fiqa:01JPQE6H01XHG7HJBYKX2QWVQQ',
#  'fiqa:01JPQE6H01C1EETYB4AW1B3GKC',
#  'fiqa:01JPQE6H01JWKF8TX2SKHWSN73',
#  'fiqa:01JPQE6H01NE4Z80YREDH9K59E',
#  'fiqa:01JPQE6H015Y4FH30J56A8CQ8Z',
#  'fiqa:01JPQE6H01J5JX2VBHT738579R',
#  'fiqa:01JPQE6H01BF9MFSQC1PWNEMM1',
#  'fiqa:01JPQE6H01JZ20172MA9HFCPQ3',
#  'fiqa:01JPQE6H011661FAYBB4985MD9',
#  'fiqa:01JPQE6H01KWXJYBG4P1APGHD6',
#  'fiqa:01JPQE6H01D3H0MBVEMPYMF6D3',
#  'fiqa:01JPQE6H01YGWKDNG7WRKKMMFA',
#  'fiqa:01JPQE6H01V0MQW48392AB1GBR',
#  'fiqa:01JPQE6H01G7NM1RWKF91N2EXR',
#  'fiqa:01JPQE6H0198EEMV2N55WYK60K',
#  'fiqa:01JPQE6H01THTGBQXS2ZFN86W2',
#  'fiqa:01JPQE6H016XH1DVF32YS3NGRG',
#  'fiqa:01JPQE6H01SZMQ0MVE51TJMDH1',
#  'fiqa:01JPQE6H01W9QK1V2HDS99P8BQ',
#  'fiqa:01JPQE6H01Y2ZDGSKZJ1W2P779',
#  'fiqa:01JPQE6H01NYGTWBP53V1BQA77',
#  'fiqa:01JPQE6H01412RN6KN163QB5B0',
#  'fiqa:01JPQE6H018A9G7HRDNVR2MTK1',
#  'fiqa:01JPQE6H01JK7VGJEAFHCE8JN8',
#  'fiqa:01JPQE6H01S8RBS0DES9R8RWWP',
#  'fiqa:01JPQE6H01ZMTMQAVB3T58DRXP',
#  'fiqa:01JPQE6H01WCNKSS324R8F4RKR',
#  'fiqa:01JPQE6H01CDJNV77VY5ZDJA4Z',
#  'fiqa:01JPQE6H01DJX144CTBY91PM95',
#  'fiqa:01JPQE6H01KQDW54HARE42BPH2',
#  'fiqa:01JPQE6H012Q2DRMZYNVSM5019',
#  'fiqa:01JPQE6H0156F5NGVZ3PA36E9J',
#  'fiqa:01JPQE6H018T3R47M12S7Y20W7',
#  'fiqa:01JPQE6H01CJQXC7CXADWQ13YA',
#  'fiqa:01JPQE6H01177RRPSVG8AD59TY',
#  'fiqa:01JPQE6H01J46MDTGTH4CYMNBN',
#  'fiqa:01JPQE6H01MBYNS1NCAQWWJVDK',
#  'fiqa:01JPQE6H01R87K8ZQSP284FVZX',
#  'fiqa:01JPQE6H0160D2FESXT4JZCXMM',
#  'fiqa:01JPQE6H011NCMPEHN1Z6Q9MYT',
#  'fiqa:01JPQE6H01H3WPR13GJPGNC6M8',
#  'fiqa:01JPQE6H01YSRV289HSZ6PPSZ9',
#  'fiqa:01JPQE6H01VH6VZYYWEF0B8H42',
#  'fiqa:01JPQE6H017N69PH52W5J0M0PM',
#  'fiqa:01JPQE6H01NV8XJWSE5MYX9FRQ',
#  'fiqa:01JPQE6H01Q6Z84HJ1W8NCCRNT',
#  'fiqa:01JPQE6H010XZ9BVN1JXF27GDV',
#  'fiqa:01JPQE6H01ERYM3J5G776RE675',
#  'fiqa:01JPQE6H2M9P5VD4XB5HNXQPHQ',
#  'fiqa:01JPQE6H2M4WNF8H79C18BG631',
#  'fiqa:01JPQE6H2MTQ520R8RZ88PKP1E',
#  'fiqa:01JPQE6H2MK46DHE81ZBCZNQP9',
#  'fiqa:01JPQE6H2MWQ2MTJVMP43834WW',
#  'fiqa:01JPQE6H2M99VGP40J4F2G4NYV',
#  'fiqa:01JPQE6H2MVZXPZ7M06ZWWBVQ7',
#  'fiqa:01JPQE6H2M9YBTZ5G3T3S7VN5C',
#  'fiqa:01JPQE6H2MT4060EYPY9BD4N9B',
#  'fiqa:01JPQE6H2M2GSS6XWMJDGFPPTF',
#  'fiqa:01JPQE6H2MFC3YXQ9NBNPFHB4X',
#  'fiqa:01JPQE6H2M4R5R0M7AV3NA5HJS',
#  'fiqa:01JPQE6H2MNR9M7F0VZETAGSDG',
#  'fiqa:01JPQE6H2M13AXVVZWN461C105',
#  'fiqa:01JPQE6H2MMTM43A37DVF289FQ',
#  'fiqa:01JPQE6H2MX8AM2VSTT7X2ZD3M',
#  'fiqa:01JPQE6H2MA8YGDSF83RB947YW',
#  'fiqa:01JPQE6H2MC4J9SZ62G78DFJRC',
#  'fiqa:01JPQE6H2M3AWCAT05QPB16HTP',
#  'fiqa:01JPQE6H2M68QMW7QE953DXYHB',
#  'fiqa:01JPQE6H2MSJ1BF88R60K0KHYF',
#  'fiqa:01JPQE6H2MMD9X5FQYS7V5WR8P',
#  'fiqa:01JPQE6H2MDYRD8T21KAEFYEC5',
#  'fiqa:01JPQE6H2MBY4EPE1QP89D2NPW',
#  'fiqa:01JPQE6H2M3QG3017T03M91VRS',
#  'fiqa:01JPQE6H2MBJ207R34CSX2GZ5S',
#  'fiqa:01JPQE6H2MV4C44GVHNB5X0Y8B',
#  'fiqa:01JPQE6H2MWECWRS16SF62AD25',
#  'fiqa:01JPQE6H2MD3BBX56TY25EYAH2',
#  'fiqa:01JPQE6H2MENGXM4V259BJYES6',
#  'fiqa:01JPQE6H2MNQEHWDMA9AKTYWP8',
#  'fiqa:01JPQE6H2M1MR7JD50YVN2K8M2',
#  'fiqa:01JPQE6H2ME4TBXWZYBS2Q7VT6',
#  'fiqa:01JPQE6H2MS2C2XYGQDBE00BQR',
#  'fiqa:01JPQE6H2MWJ90KZ1H9JE7QPJ5',
#  'fiqa:01JPQE6H2M5N2NJKJQ39BYW8TN',
#  'fiqa:01JPQE6H2MX87C40KKGSKQEM40',
#  'fiqa:01JPQE6H2MDZS5SNJNCM9G72JV',
#  'fiqa:01JPQE6H2M24AVNBAH2FG7392Q',
#  'fiqa:01JPQE6H2MZV0PQGS8RQBBGTEP',
#  'fiqa:01JPQE6H2MJE21ZDD8BRZNDPG5',
#  'fiqa:01JPQE6H2MPQ32TJ5HFFQKQSPY',
#  'fiqa:01JPQE6H2MBAHR1KYKFFRRSDE5',
#  'fiqa:01JPQE6H2N8EG097AXBYT2RF42',
#  'fiqa:01JPQE6H2NNXKQSH9SWA701ZG6',
#  'fiqa:01JPQE6H2NR9NFY9TKFAXTVJ76',
#  'fiqa:01JPQE6H2NYG5KNA72GJE1BR00',
#  'fiqa:01JPQE6H2NRH72VB09B7YRS7JZ',
#  'fiqa:01JPQE6H2NRSC3WCJERHFVQJ5V',
#  'fiqa:01JPQE6H2NP0G9SV5SEYAH3P3K',
#  'fiqa:01JPQE6H2NB7NGEPSA0BYDCJM1',
#  'fiqa:01JPQE6H2N7F1RQBWZGXQDQS6W',
#  'fiqa:01JPQE6H2NJZ4400BVQAFQ7QR4',
#  'fiqa:01JPQE6H2NJT78022BPRNH50QX',
#  'fiqa:01JPQE6H2NRZ89PPY6TDY4CNV2',
#  'fiqa:01JPQE6H2NVZCPJKZRXVSZ1PMZ',
#  'fiqa:01JPQE6H2NX1XFN07KPRDCDZJV',
#  'fiqa:01JPQE6H2NTQSCYCE3HYK4HHBK',
#  'fiqa:01JPQE6H2N0X0D55KMC0XG2GQ8',
#  'fiqa:01JPQE6H2NXT2R94Y2HYYVMZJH',
#  'fiqa:01JPQE6H2NP9KWKXD084XW4VB9',
#  'fiqa:01JPQE6H2NKQA0THK53MY73464',
#  'fiqa:01JPQE6H2NF9VFQ238VCTMAVZC',
#  'fiqa:01JPQE6H2NMSVBVAVR6RVF195G',
#  'fiqa:01JPQE6H2NFYMMHX6D0X2V8ERR',
#  'fiqa:01JPQE6H2NJ5EM41HQ8D4QW138',
#  'fiqa:01JPQE6H2NFEDF4115GR30BVDB',
#  'fiqa:01JPQE6H2NDSMMW9V66NW08CMH',
#  'fiqa:01JPQE6H2NVEY0CF6VEB72X7CV',
#  'fiqa:01JPQE6H2NCP4RXYCYG3FMB83H',
#  'fiqa:01JPQE6H2NQEM3GFXT1JRXAA52',
#  'fiqa:01JPQE6H2N2B47ZY3PW8CXS0MR',
#  'fiqa:01JPQE6H2NPDPVYD9793TZNTGJ',
#  'fiqa:01JPQE6H2NE4WH4DNF6PDMJW40',
#  'fiqa:01JPQE6H2NK6MQYFMJCZHEME86',
#  'fiqa:01JPQE6H2N40GXB1Y6NGCC07FF',
#  'fiqa:01JPQE6H2NCE6ANFNSBKD6N5KQ',
#  'fiqa:01JPQE6H2NA3C1B31G3FZDGCGM',
#  'fiqa:01JPQE6H2N3C76WEZDYGAJ5H8W',
#  'fiqa:01JPQE6H2NF7383VW86QJXABJW',
#  'fiqa:01JPQE6H2NBMTGH6AFH4BGA3KR',
#  'fiqa:01JPQE6H2NVXQ176XRKYGE2DKH',
#  'fiqa:01JPQE6H2NR2P2EWZZB8DHDX90',
#  'fiqa:01JPQE6H2N2R9XJW7PC6M3APDQ',
#  'fiqa:01JPQE6H2NJS0GP9YZC7FSMH9C',
#  'fiqa:01JPQE6H2NKCME024JGY7BF2B5',
#  'fiqa:01JPQE6H2NERCG1ZDMJCFZP7HN',
#  'fiqa:01JPQE6H2NF6GXJNABYTA3H2M1',
#  'fiqa:01JPQE6H2NBG1N7J7HF265207G',
#  'fiqa:01JPQE6H2NHKAMS1R9PA7E80VR',
#  'fiqa:01JPQE6H2NYH4XC1M06X7KAW26',
#  'fiqa:01JPQE6H2NSC6T1F2SYJXNXHVT',
#  'fiqa:01JPQE6H2N13TZGA5CWECQZQGS',
#  'fiqa:01JPQE6H2NPEP36EYT1KGYDDTT',
#  'fiqa:01JPQE6H2N22N87RFRA6BANR4N',
#  'fiqa:01JPQE6H2NAF50H47SY1PYFG3Q',
#  'fiqa:01JPQE6H2NYS3ARS0WRYV89M2W',
#  'fiqa:01JPQE6H2N9BTV4RSD9P2XZ1V8',
#  'fiqa:01JPQE6H2NQJCFZ3JMA693ACWA',
#  'fiqa:01JPQE6H2NRM3HST77M1C5ZTAA',
#  'fiqa:01JPQE6H2NHDZGD56AX8MHF5Q7',
#  'fiqa:01JPQE6H2N5T4MT3NAHFH23714',
#  'fiqa:01JPQE6H2N1NFVSN2BM25P18GR',
#  'fiqa:01JPQE6H2NDYHES3RQBGHE1K13',
#  'fiqa:01JPQE6H2N6Q4G1WK6YK4MGNH3',
#  'fiqa:01JPQE6H2N88S4ENS094RJSQX6',
#  'fiqa:01JPQE6H2NRT5R0Y6XRWE3HXJA',
#  'fiqa:01JPQE6H2NCV85CZWF4RWE46HF',
#  'fiqa:01JPQE6H2NK6A9SBQ7ZY0WPQDA',
#  'fiqa:01JPQE6H2NHSSBWW55SABXT60G',
#  'fiqa:01JPQE6H2NW1AWYZHMAGZPV521',
#  'fiqa:01JPQE6H2NW4EV7JQHV8JNC4AF',
#  'fiqa:01JPQE6H2NZBVWP3AMVT5YQGYA',
#  'fiqa:01JPQE6H2N1MXNAW8CW1S5AQJQ',
#  'fiqa:01JPQE6H2N6ZX8FJV08JFDYHWH',
#  'fiqa:01JPQE6H2NJ6PY0H83PDBYYAT0',
#  'fiqa:01JPQE6H2NPQJHJ4R0V5E1WY3B',
#  'fiqa:01JPQE6H2NP8YPA089VVTZJ1M6',
#  'fiqa:01JPQE6H2N4K106D4SG3FZFJVG',
#  'fiqa:01JPQE6H2N9P7F9NTMWFNFDWJA',
#  'fiqa:01JPQE6H2N6EBQG8KXE4HZXSY3',
#  'fiqa:01JPQE6H2NQ0H3RR3Q90ET4H9Z',
#  'fiqa:01JPQE6H2N4118XGBKKXEWJ6YN',
#  'fiqa:01JPQE6H2NVHK8RSV1ZH22YEJM',
#  'fiqa:01JPQE6H2NQNM9W19B5RV35K8C',
#  'fiqa:01JPQE6H2N38RGN617PP9K5MYS',
#  'fiqa:01JPQE6H2NH2GQ3QW98N8G0YTG',
#  'fiqa:01JPQE6H2N6TDB3MEM1QDEEWD2',
#  'fiqa:01JPQE6H2N6NZD1TJFA9YC2S1H',
#  'fiqa:01JPQE6H2N5JTP63G0CTDR3CYB',
#  'fiqa:01JPQE6H2NNZZ76BPHW03SKMER',
#  'fiqa:01JPQE6H2NTNZ9QQ5SRD8BC1N7',
#  'fiqa:01JPQE6H2N7AAJV8707TBF0DWW',
#  'fiqa:01JPQE6H2NMQMPHC7EDP8A8E2D',
#  'fiqa:01JPQE6H2NDDQTKJB1HTRHTC9V',
#  'fiqa:01JPQE6H2NK8CQG5A89341268G',
#  'fiqa:01JPQE6H2N4GNVAZ79M3GXQG9F',
#  'fiqa:01JPQE6H2NX7G34Q5AVC5WRTG9',
#  'fiqa:01JPQE6H2NF6CY77NGKA4H3XWV',
#  'fiqa:01JPQE6H2NKGQT1PS4VKVJ0AFW',
#  'fiqa:01JPQE6H2NJ163VR13SGQRW4X9',
#  'fiqa:01JPQE6H2NN0B017S3HMD5B5Q1',
#  'fiqa:01JPQE6H2N598ZEDTS7CZP1HYG',
#  'fiqa:01JPQE6H2N7CMGWJ77SV33HM1C',
#  'fiqa:01JPQE6H2NGYV21RNQ1WBT1V19',
#  'fiqa:01JPQE6H2N4JBFAJVFN5WGVCM7',
#  'fiqa:01JPQE6H2NP5EYC894XWNN0BPT',
#  'fiqa:01JPQE6H2NB88R8E0VTTEZV20F',
#  'fiqa:01JPQE6H2NSRBTY3TSZ5K4MF7J',
#  'fiqa:01JPQE6H2NPQRBV0RFM3XX2770',
#  'fiqa:01JPQE6H2N2M3GYZP2Y7QRJ0K2',
#  'fiqa:01JPQE6H2NKZF82H3KW84GCYHQ',
#  'fiqa:01JPQE6H2NVE9K7S0330Y42QZ4',
#  'fiqa:01JPQE6H2NXYW8T1E7B3WRAYW1',
#  'fiqa:01JPQE6H2NZ015PE0C2EC9KD4Y',
#  'fiqa:01JPQE6H2NV0Z404J0MSSY56Z4',
#  'fiqa:01JPQE6H2NGV32K3E4YFC0ATM3',
#  'fiqa:01JPQE6H2NHP3Z5BZ0RKDTG5WM',
#  'fiqa:01JPQE6H2N1CCVR6ZH2GHH1M6J',
#  'fiqa:01JPQE6H2N6TWGD3ZRG949568K',
#  'fiqa:01JPQE6H2NV4XMA3EQF2594KN7',
#  'fiqa:01JPQE6H2NNZNSR2GGSJJKTPKK',
#  'fiqa:01JPQE6H2N1MQ5JGEAY89RMHJG',
#  'fiqa:01JPQE6H2NW4AGJM2N0X5V1DDD',
#  'fiqa:01JPQE6H2NAQWVCV0WWS9ZG5R4',
#  'fiqa:01JPQE6H2N7DFR1EZ21YRWHHTZ',
#  'fiqa:01JPQE6H2NVKQB761404BN4R2J',
#  'fiqa:01JPQE6H2NT5797TCCV0TV6VH6',
#  'fiqa:01JPQE6H2N8C1VK9TYNR49W3PC',
#  'fiqa:01JPQE6H2NGE964X58Z061P60H',
#  'fiqa:01JPQE6H2N8XVKJHT42E8VVTEJ',
#  'fiqa:01JPQE6H2NT28BP8G6644MR3WN',
#  'fiqa:01JPQE6H2NRMX4X5CDPEFHGW2Y',
#  'fiqa:01JPQE6H2N09CTGZ8NCGQXY9H6',
#  'fiqa:01JPQE6H2NQ6ZGP2F7VR8B19R3',
#  'fiqa:01JPQE6H2NTJYTWGG1S4RBFGT8',
#  'fiqa:01JPQE6H2NT4Z58QCFSRJ8A24J',
#  'fiqa:01JPQE6H2N017QHRR0JYRD1Q44',
#  'fiqa:01JPQE6H2NNFAEZE57A7PT4W8A',
#  'fiqa:01JPQE6H2NTM1EMH6CJRFHJZ52',
#  'fiqa:01JPQE6H2N4SA35JQRVTFT8RDM',
#  'fiqa:01JPQE6H2N27AHMRB8V23QX857',
#  'fiqa:01JPQE6H2NNDF7V304PVFCQSB1',
#  'fiqa:01JPQE6H2NTH815XKZ8QHY36EA',
#  'fiqa:01JPQE6H2NZ69ACFPW00NK40YR',
#  'fiqa:01JPQE6H2NTMKNGPBX5097ENDS',
#  'fiqa:01JPQE6H2NCRTBYB8DKV0WG4MQ',
#  'fiqa:01JPQE6H2NQBC9EGTYZYP0AAVN',
#  'fiqa:01JPQE6H2N24WER53VXZQWFV4G',
#  'fiqa:01JPQE6H2NV9FSYW4X0Q625YFP',
#  'fiqa:01JPQE6H2N46J749AG5FFT4VM9',
#  'fiqa:01JPQE6H2N2CFE8EJTN16K91CC',
#  'fiqa:01JPQE6H2NMS8CVT5VKPEHS1K9',
#  'fiqa:01JPQE6H2NK9MERH692AREHHB3',
#  'fiqa:01JPQE6H2NWM2EWRHPDNMZ4H9D',
#  'fiqa:01JPQE6H2NSE7BWSB38Y6CKN61',
#  'fiqa:01JPQE6H2N7ENFDFSX140NC25D',
#  'fiqa:01JPQE6H2NKGX8T3MHYD592V9A',
#  'fiqa:01JPQE6H2NKZGFZ8M1PFMNCQVC',
#  'fiqa:01JPQE6H2NQGJ93V97P5RPY4N8',
#  'fiqa:01JPQE6H5RNCV5FQSYWX1YDDGW',
#  'fiqa:01JPQE6H5R5DJQ85Q108A798BG',
#  'fiqa:01JPQE6H5R6E3Y89T1WYH9YDQ1',
#  'fiqa:01JPQE6H5RWPQNT7DH1RPK2DYX',
#  'fiqa:01JPQE6H5REVJ72H6BWX9C7JD7',
#  'fiqa:01JPQE6H5RSWFSA3E5N8K4MFPN',
#  'fiqa:01JPQE6H5RDRCXS8YGDR99M735',
#  'fiqa:01JPQE6H5REYVTSWHAGEPH8FZP',
#  'fiqa:01JPQE6H5RGC1ADA97T3499Y48',
#  'fiqa:01JPQE6H5R1BK27JFJ6YPB3BGM',
#  'fiqa:01JPQE6H5RN81391Z14XKQ91EX',
#  'fiqa:01JPQE6H5RVDFVRHA710F4RBX0',
#  'fiqa:01JPQE6H5RME25NBWQN1Y9Z3HV',
#  'fiqa:01JPQE6H5R3WHJQVVWJM443Y77',
#  'fiqa:01JPQE6H5RKGZ2NV2EPFZ0JSSP',
#  'fiqa:01JPQE6H5RGDQ0KQ1PDT7R2WN0',
#  'fiqa:01JPQE6H5R9WQC2HR104V5PP89',
#  'fiqa:01JPQE6H5RF5BYK6T23B1PM6GG',
#  'fiqa:01JPQE6H5RW394B8WAZAB03NSG',
#  'fiqa:01JPQE6H5RY0RT9B6Z7E9SM7HV',
#  'fiqa:01JPQE6H5RDCFZ3KYB74N11Q3F',
#  'fiqa:01JPQE6H5R6JTJ2X80FACS641C',
#  'fiqa:01JPQE6H5RQQCPN2F4VN5RCARN',
#  'fiqa:01JPQE6H5R7BGYSGQZE2J12YR3',
#  'fiqa:01JPQE6H5R3DAG6KW3T1AHWZR1',
#  'fiqa:01JPQE6H5RK3Y1YN0R8JBRABXN',
#  'fiqa:01JPQE6H5RPV735F8AAG14ETJ1',
#  'fiqa:01JPQE6H5RB0V44YE8KR1T8DHB',
#  'fiqa:01JPQE6H5R4QYHMTG9MR7DR4FD',
#  'fiqa:01JPQE6H5RVH0RNJ1BMS86WZZD',
#  'fiqa:01JPQE6H5RHNGPR6KN13DAS28R',
#  'fiqa:01JPQE6H5R4BJ6F85CFAT4GCHH',
#  'fiqa:01JPQE6H5R36W4HCKC61576RMF',
#  'fiqa:01JPQE6H5RP3PSVPFHWP7B622C',
#  'fiqa:01JPQE6H5RQ1RXKYM8DK7WSSYB',
#  'fiqa:01JPQE6H5R5G1SV9T52EVMFHF2',
#  'fiqa:01JPQE6H5R52GQS9C33ZPN9B38',
#  'fiqa:01JPQE6H5R5CGB6S43RZWBYBER',
#  'fiqa:01JPQE6H5RP9FV2KRV5E5K9R7F',
#  'fiqa:01JPQE6H5RYAYFPJQXK2D3TYQ4',
#  'fiqa:01JPQE6H5R3W5YT0K08E34J13J',
#  'fiqa:01JPQE6H5R5P4CT7VGRG0RX1RZ',
#  'fiqa:01JPQE6H5RHA3YPYPQ6RX5KC96',
#  'fiqa:01JPQE6H5RJ05CG95YBQ77TXVV',
#  'fiqa:01JPQE6H5RWS2K5B07N35RGGHE',
#  'fiqa:01JPQE6H5R0QQET0AQHF2J65Y0',
#  'fiqa:01JPQE6H5RDB6MFEYDZC0HQ07A',
#  'fiqa:01JPQE6H5RG3JTP8EVNH9V1MVK',
#  'fiqa:01JPQE6H5RV7WZWY2TR17MNK6H',
#  'fiqa:01JPQE6H5R2SV79X52DDDKME8T',
#  'fiqa:01JPQE6H5RM8XX8RK4V70A133E',
#  'fiqa:01JPQE6H5R1G101CZ9EF5WA976',
#  'fiqa:01JPQE6H5R2CEJ1RJ32BHWGAA2',
#  'fiqa:01JPQE6H5RQEN4S6KY2H7X9KEB',
#  'fiqa:01JPQE6H5RKN0ZYW76PCY98SQJ',
#  'fiqa:01JPQE6H5R2G19KZX1GTN2NX01',
#  'fiqa:01JPQE6H5R58CBDNDPKAY3N8H2',
#  'fiqa:01JPQE6H5RQ861X4JSYPJ31BJD',
#  'fiqa:01JPQE6H5RENRPAX0C1WW0W94K',
#  'fiqa:01JPQE6H5R3VRHG4MR82ZQR1C5',
#  'fiqa:01JPQE6H5R5ACV848NMS39MX51',
#  'fiqa:01JPQE6H5R4DC153QFDMJYF0J0',
#  'fiqa:01JPQE6H5R1DEMTSZT1XXEFCQC',
#  'fiqa:01JPQE6H5RDZ98DSEA5EMEQR75',
#  'fiqa:01JPQE6H5RAEA3YEYAVYR0B26F',
#  'fiqa:01JPQE6H5R64JK65P43HKTP6ZD',
#  'fiqa:01JPQE6H5RS74QMNF2FFS00Q19',
#  'fiqa:01JPQE6H5RAY76STTQCE184K13',
#  'fiqa:01JPQE6H5R7MAS1VBBW8MD33JW',
#  'fiqa:01JPQE6H5R1498DBKTJVXB91ZQ',
#  'fiqa:01JPQE6H5R09N3MEW7DCHAT46H',
#  'fiqa:01JPQE6H5RHNNMSXCW16DNQA3T',
#  'fiqa:01JPQE6H5RZSP9AM4DKQ0XQQ1D',
#  'fiqa:01JPQE6H5RZ1V2WA3DG02FSKYW',
#  'fiqa:01JPQE6H5RRGVKY90BNX8MX9T8',
#  'fiqa:01JPQE6H5RGJBZ80TH26HRTAND',
#  'fiqa:01JPQE6H5RAZS8S1XX5EFHWVHK',
#  'fiqa:01JPQE6H5RKBAKH72GK1KGYJ7A',
#  'fiqa:01JPQE6H5RH0284Z8DB6NSYZ7W',
#  'fiqa:01JPQE6H5RMEEPRBWR6GX7XM8P',
#  'fiqa:01JPQE6H5RZQ1SXE5ZKC4SVAY0',
#  'fiqa:01JPQE6H5RHN93W01WNYFDFC43',
#  'fiqa:01JPQE6H5R295YBBC7AVNEEB6N',
#  'fiqa:01JPQE6H5RDQJ52RAGM0GV565H',
#  'fiqa:01JPQE6H5RJH1W827915QJ58NE',
#  'fiqa:01JPQE6H5R6B05Y634S5KKQYAW',
#  'fiqa:01JPQE6H5RDJQPDAQQDSMQ70TP',
#  'fiqa:01JPQE6H5RP51ZVF6XMW2RW86B',
#  'fiqa:01JPQE6H5RAK3VPWJW2Y0XERQM',
#  'fiqa:01JPQE6H5RCSHQ5Y7KYWJXHXSH',
#  'fiqa:01JPQE6H5R13PFE71J4ZSAS9C2',
#  'fiqa:01JPQE6H5RVBJQ6TJKGWPR4K95',
#  'fiqa:01JPQE6H5R8AJHV88W7PVYHY7J',
#  'fiqa:01JPQE6H5RSXJK3AGB0HHE4G81',
#  'fiqa:01JPQE6H5RGHDJZAJX1R2ZFC8F',
#  'fiqa:01JPQE6H5RA3R07X8KK6TKXYRX',
#  'fiqa:01JPQE6H5R07HBQSTKY2YRQA1D',
#  'fiqa:01JPQE6H5RW8H5WJWM2Q5JG5JA',
#  'fiqa:01JPQE6H5R8EBTBWR4KBC354X1',
#  'fiqa:01JPQE6H5RMF4W4N5MZJVPGXH3',
#  'fiqa:01JPQE6H5RXJQY57SPT1FAJJG8',
#  'fiqa:01JPQE6H5RND5K23SBV0KZVT6Y',
#  'fiqa:01JPQE6H5RFBZVWMDF9BB5SA5P',
#  'fiqa:01JPQE6H5R148MC93QXJF2CTMH',
#  'fiqa:01JPQE6H5RQ90YJ467Q8AYG818',
#  'fiqa:01JPQE6H5RGHPNGWWNEXQ33D3R',
#  'fiqa:01JPQE6H5RW0MCFKMXKNHG0Q90',
#  'fiqa:01JPQE6H5RKZ24HCCYZCH8QGET',
#  'fiqa:01JPQE6H5RGBANYDAP383V29A4',
#  'fiqa:01JPQE6H5R6R3Q42H4WVQDRF78',
#  'fiqa:01JPQE6H5RKEN01A9BHMPSP3BC',
#  'fiqa:01JPQE6H5RPFJC4N2SAEF38M3N',
#  'fiqa:01JPQE6H5R657ZR6BFEBKYH6B4',
#  'fiqa:01JPQE6H5RZ641D30RS34ABCBP',
#  'fiqa:01JPQE6H5SAYNQE8EZX86Y43P3',
#  'fiqa:01JPQE6H5SNK9ZFSK3NAC32XH2',
#  'fiqa:01JPQE6H5S7815RVBDDXHYPZC8',
#  'fiqa:01JPQE6H5SDA29ZNYM3AYE1DXV',
#  'fiqa:01JPQE6H5SYFCG6JK2D6R1ZABY',
#  'fiqa:01JPQE6H5SQ32P6MY8DJ2D8DFR',
#  'fiqa:01JPQE6H5S3EWWY4F0VVPTQ1ZK',
#  'fiqa:01JPQE6H5SQBJY3HJ78DC8KJBR',
#  'fiqa:01JPQE6H5SVE1741JV4F2TZC21',
#  'fiqa:01JPQE6H5S2WCF9JWXGGYKJ6PX',
#  'fiqa:01JPQE6H5S6J1M3778SH5NPBVJ',
#  'fiqa:01JPQE6H5S4CFD0QVWW66WZF4W',
#  'fiqa:01JPQE6H5SG587F31WWN0627RB',
#  'fiqa:01JPQE6H5SDSBKVE6X8YNNK6XP',
#  'fiqa:01JPQE6H5SK380BEDA6B4HS2SP',
#  'fiqa:01JPQE6H5S6WK3ZK621MYJBDRH',
#  'fiqa:01JPQE6H5S2KEFFAP34Q6CEEQS',
#  'fiqa:01JPQE6H5SECBTEK713B1TH359',
#  'fiqa:01JPQE6H5S129PG5THSXBNSC4C',
#  'fiqa:01JPQE6H5S2B2PKCPCDHSJ616Z',
#  'fiqa:01JPQE6H5STBCMYMXZ3TNM1E6F',
#  'fiqa:01JPQE6H5SJTHX7Y3HKP5WR8WK',
#  'fiqa:01JPQE6H5S8JZXNX3MKE18RZ6Q',
#  'fiqa:01JPQE6H5S9W2PVXJ2GQ3M4SP7',
#  'fiqa:01JPQE6H5SVKW8RVKCMP7VHEF5',
#  'fiqa:01JPQE6H5STVKAH2Q4S7F5CR3A',
#  'fiqa:01JPQE6H5S9Y3PXB7N8J9KT5JH',
#  'fiqa:01JPQE6H5SMTZ55YFTNJ3J4DH2',
#  'fiqa:01JPQE6H5SPT8FWYWT8JE9ZQFD',
#  'fiqa:01JPQE6H5SVZWX426JGQVRGNF6',
#  'fiqa:01JPQE6H5S9B5KMHNP0JVD474T',
#  'fiqa:01JPQE6H5SBPGEBCMR0RGNX51N',
#  'fiqa:01JPQE6H5SBBY1CVMSV0RFMYGX',
#  'fiqa:01JPQE6H5SETSJZ1BZBQC8V277',
#  'fiqa:01JPQE6H5SFHEWXEM2C9Z70D0D',
#  'fiqa:01JPQE6H5S3MP0Q14G9FB7Z8N8',
#  'fiqa:01JPQE6H5S0DCZKHFRPP6FJJAS',
#  'fiqa:01JPQE6H5SC74YSE2JNME2QB12',
#  'fiqa:01JPQE6H5SWBTXFPXQV32ZG2Q4',
#  'fiqa:01JPQE6H5SYTKK8JN46APB20AD',
#  'fiqa:01JPQE6H5SJQCTPW7Y6G1EQJ7W',
#  'fiqa:01JPQE6H5SR4MGJ5R91HAMD90R',
#  'fiqa:01JPQE6H5S6QPG5ZA606KXJ1TT',
#  'fiqa:01JPQE6H5SVWQXZHTPNX13NJDT',
#  'fiqa:01JPQE6H5STCFY7XQWFYESQ319',
#  'fiqa:01JPQE6H5SV29Q9AHTF8XBXFXV',
#  'fiqa:01JPQE6H5SFV4CTYVG38GVJZRM',
#  'fiqa:01JPQE6H5STTQZQ8T6V5D5WDMN',
#  'fiqa:01JPQE6H5SXC8JZM0WAB89KRPJ',
#  'fiqa:01JPQE6H5SXZB1ZNQSFPQT3QF7',
#  'fiqa:01JPQE6H5SZJQZMBHE08WQR57Y',
#  'fiqa:01JPQE6H5STSHE1K66Q9SBJSJP',
#  'fiqa:01JPQE6H5S1445DCCF98AFNXKM',
#  'fiqa:01JPQE6H5SV7AESC45EQ77JXFR',
#  'fiqa:01JPQE6H5SGSFRN3TSQD388ETF',
#  'fiqa:01JPQE6H5SCQQXMENSHPCA4Q10',
#  'fiqa:01JPQE6H5SKECPE96HDN4AYTJT',
#  'fiqa:01JPQE6H5SVEZASRVVRHY8FJHX',
#  'fiqa:01JPQE6H5SFZEDA20HAZGJR3XW',
#  'fiqa:01JPQE6H5SKVZWSFHQ0X3JVC54',
#  'fiqa:01JPQE6H5SD2PX3RAWD77JC6ZH',
#  'fiqa:01JPQE6H5S4M33SXXJWXYJ7J6S',
#  'fiqa:01JPQE6H5STNTW6HFXJ8TT228W',
#  'fiqa:01JPQE6H5S4ECZMDEQFEN1N196',
#  'fiqa:01JPQE6H5SE4FD7ETWKMSES2Z9',
#  'fiqa:01JPQE6H5SE388RWDEK8XGA9QW',
#  'fiqa:01JPQE6H5SHETHZY1YS4YB9SPD',
#  'fiqa:01JPQE6H5ST4C2MB399P2QE638',
#  'fiqa:01JPQE6H5SVKEEJBR9MH8EQSQV',
#  'fiqa:01JPQE6H5SCT3KW9ST573J1JX1',
#  'fiqa:01JPQE6H5STZVBP7VDAG2A28K9',
#  'fiqa:01JPQE6H5SS6S0Y2T4P8ZWPMDH',
#  'fiqa:01JPQE6H5S02SVJH103BYTP2SG',
#  'fiqa:01JPQE6H5SC0RK60S3S0027KGH',
#  'fiqa:01JPQE6H5SSX34NSD5RYS22K5D',
#  'fiqa:01JPQE6H5S40FZDNA581GF3EYF',
#  'fiqa:01JPQE6H5ST1VPTC03HVDYHFCJ',
#  'fiqa:01JPQE6H5S5Z50PF7262MJ37FM',
#  'fiqa:01JPQE6H5SV5NX0PKN0CJP11S6',
#  'fiqa:01JPQE6H5S7PRXZHK6N51EAJJQ',
#  'fiqa:01JPQE6H5SA3VVQ3V6SWZW2GMF',
#  'fiqa:01JPQE6H5SVGGJ1G5Y9RMPWGPE',
#  'fiqa:01JPQE6H5S3VRW3V5QK8W0XCZD',
#  'fiqa:01JPQE6H5SFKDSN91C3WRVZHGH',
#  'fiqa:01JPQE6H5SF5GNTG8ZSW55RPM9',
#  'fiqa:01JPQE6H5SK80F4DW9NHQZ0RQH',
#  'fiqa:01JPQE6H98HZQG3CSNSD0422WQ',
#  'fiqa:01JPQE6H99ZJTHM6003Q2HKHXN',
#  'fiqa:01JPQE6H99MXEYQYWBPCH1TD3S',
#  'fiqa:01JPQE6H99HBVZ9JAS6BBHM8WD',
#  'fiqa:01JPQE6H99YGYAYDWQ4PCXS7HQ',
#  'fiqa:01JPQE6H995RV46CXHX5J03PHJ',
#  'fiqa:01JPQE6H998PX3PPAW5XF0DSPC',
#  'fiqa:01JPQE6H9941DH2R56C8GQS60X',
#  'fiqa:01JPQE6H992EPD26C374CDYH0E',
#  'fiqa:01JPQE6H99W9XAZ8FNN5MF4TV1',
#  'fiqa:01JPQE6H99KHXX61WMR4T3RKBY',
#  'fiqa:01JPQE6H997C6NRAN5935T17SN',
#  'fiqa:01JPQE6H99861SS1HXH0WEZTCJ',
#  'fiqa:01JPQE6H99NKZW1G5VD89TDW9F',
#  'fiqa:01JPQE6H994TSJRCJ9T1D8CTX5',
#  'fiqa:01JPQE6H99QB607TF0TV30T3A5',
#  'fiqa:01JPQE6H99GC1PDM2A2W5SZWN4',
#  'fiqa:01JPQE6H9A10PFTXTEGD55NY8W',
#  'fiqa:01JPQE6H9ARQ4ZMW4P0G1MTPKX',
#  'fiqa:01JPQE6H9AVKFMMCHYKQW9NW7Y',
#  'fiqa:01JPQE6H9AJ3GXQY8R1MFJYP19',
#  'fiqa:01JPQE6H9A2E2N24DW6SMCZFQP',
#  'fiqa:01JPQE6H9A0HXYSK3E9XTP6G62',
#  'fiqa:01JPQE6H9AS0YDCMN293FJFT5F',
#  'fiqa:01JPQE6H9AEG589E6KMSDESEFN',
#  'fiqa:01JPQE6H9A839N4ERG765MRSCG',
#  'fiqa:01JPQE6H9AHVSVH3QGW4FK98V1',
#  'fiqa:01JPQE6H9AQ0A08WB3MFKRA8QG',
#  'fiqa:01JPQE6H9A3VB3EQPYVDVPPNQ6',
#  'fiqa:01JPQE6H9AXZJ30W4F3MP6JDN9',
#  'fiqa:01JPQE6H9ACY0XBG50JBB4803G',
#  'fiqa:01JPQE6H9AWEBJ9ZV9KM52PGRK',
#  'fiqa:01JPQE6H9AY8T07HMM5F2QD62N',
#  'fiqa:01JPQE6H9AFCRGNDVFMP3T84RS',
#  'fiqa:01JPQE6H9BZSE6MNBHQ395KZ8N',
#  'fiqa:01JPQE6H9B378ECTGMTJ40GC5C',
#  'fiqa:01JPQE6H9BCYZBQZ9F8261KE3Y',
#  'fiqa:01JPQE6H9BT5TNXK8FBQJEGW11',
#  'fiqa:01JPQE6H9BW5MA469HEV1P4D9H',
#  'fiqa:01JPQE6H9BFEFC0TGNHQ4HQAEX',
#  'fiqa:01JPQE6H9B62BTY5SJTZTWBHBX',
#  'fiqa:01JPQE6H9BMRPCTE8CSRF8D105',
#  'fiqa:01JPQE6H9BR8QFTSHTD0FVZFJ8',
#  'fiqa:01JPQE6H9BF8EKRW40B2YQ3NR7',
#  'fiqa:01JPQE6H9BGEWX8FKDNDC5E4NC',
#  'fiqa:01JPQE6H9B7EJG5EGYGA40J4SZ',
#  'fiqa:01JPQE6H9BTECPPMV3H0X8H01H',
#  'fiqa:01JPQE6H9BQG0GX2ES8QGCM7S0',
#  'fiqa:01JPQE6H9BNAM2YXQ18EKBEMZ4',
#  'fiqa:01JPQE6H9B0JN0X1NYGZ405QMZ',
#  'fiqa:01JPQE6H9BW936MXNK8S07EXWQ',
#  'fiqa:01JPQE6H9B0NNCYMP45XPGEEKK',
#  'fiqa:01JPQE6H9BJ7D0NFQ5CGN28EJ6',
#  'fiqa:01JPQE6H9B89Q7WYANTSW4TD99',
#  'fiqa:01JPQE6H9B8TE4Z2D9XC2ETD1C',
#  'fiqa:01JPQE6H9BJ3GVNF3BTREDJ74W',
#  'fiqa:01JPQE6H9BRFBS9JW6JRQ1X0JW',
#  'fiqa:01JPQE6H9BBKD36RP2JKCH2R0X',
#  'fiqa:01JPQE6H9BRNJKG2TZ5PHZFWX9',
#  'fiqa:01JPQE6H9BQ77QNR76GA3N31GD',
#  'fiqa:01JPQE6H9BJTA2BVPZ5JMG50FJ',
#  'fiqa:01JPQE6H9B1FZCWW5X8B4Q9XKB',
#  'fiqa:01JPQE6H9BTTAJKHFXS8BKWVHT',
#  'fiqa:01JPQE6H9BNZZR01GBWGXWPN6Z',
#  'fiqa:01JPQE6H9BENM3SC4JA3T3M9ZH',
#  'fiqa:01JPQE6H9BE6A0J83PNE65AGR4',
#  'fiqa:01JPQE6H9B70YYHWK7VKKX970D',
#  'fiqa:01JPQE6H9B3J8RDSV49CEQ1RAH',
#  'fiqa:01JPQE6H9B12PY78KN8VKJ41YQ',
#  'fiqa:01JPQE6H9BJWJ0F7AZB5H1FZYN',
#  'fiqa:01JPQE6H9BJ7TWXKZ4555DK3NT',
#  'fiqa:01JPQE6H9BDYCWTNWV3S1HSKP9',
#  'fiqa:01JPQE6H9BGKQEBMQP5B6PQAKW',
#  'fiqa:01JPQE6H9BMK96EFD9RE5MRK6E',
#  'fiqa:01JPQE6H9BZ4KVRA8YK90EM5PW',
#  'fiqa:01JPQE6H9B29J3WH6271BHB1NH',
#  'fiqa:01JPQE6H9BKA126QNEHJZ9WRNZ',
#  'fiqa:01JPQE6H9CMQ1CKHDRQC697J1R',
#  'fiqa:01JPQE6H9C3GBFZQPRPSKHXJGT',
#  'fiqa:01JPQE6H9C0V92W0X1TDWE2MK8',
#  'fiqa:01JPQE6H9C5RMBS42GSP0VAQ5X',
#  'fiqa:01JPQE6H9CFQBD6DCTKFA13AP8',
#  'fiqa:01JPQE6H9C73ASM1NNHQBYK7YQ',
#  'fiqa:01JPQE6H9CAZYXFDWF988PB9M2',
#  'fiqa:01JPQE6H9CBBQ3F99TM5D47EKZ',
#  'fiqa:01JPQE6H9CD185P0G9B3JKB7R1',
#  'fiqa:01JPQE6H9CPMKKGJJXX65G72AA',
#  'fiqa:01JPQE6H9CFVA2A2Y1E676W7YC',
#  'fiqa:01JPQE6H9CSG5R6GX24J9Y45AE',
#  'fiqa:01JPQE6H9C8QNWK6FGFN6NW81N',
#  'fiqa:01JPQE6H9C6KBAGHK17TJEHQ5M',
#  'fiqa:01JPQE6H9CHEH387H5Z7H1H0VP',
#  'fiqa:01JPQE6H9CBC53BYAMNAWXB921',
#  'fiqa:01JPQE6H9CVM1625568VDVN90X',
#  'fiqa:01JPQE6H9CSZ2Q3MAD5RJJQ83M',
#  'fiqa:01JPQE6H9CBMZ9KPABBD5FGA8B',
#  'fiqa:01JPQE6H9C047T0QB63SJGQ4XY',
#  'fiqa:01JPQE6H9CC3SAN28WRYMB5GTF',
#  'fiqa:01JPQE6H9C01VBA8VBHB89HM3Y',
#  'fiqa:01JPQE6H9CSEPJY6MY55VQ2Z2E',
#  'fiqa:01JPQE6H9CE69W19KV19F5D8ED',
#  'fiqa:01JPQE6H9C6HRN3DS7GK6YYQ0R',
#  'fiqa:01JPQE6H9CGMMSMT7XW7RFKN4S',
#  'fiqa:01JPQE6H9C9TW770H3QV52JJ10',
#  'fiqa:01JPQE6H9C3S0GE00H2EKR1AVF',
#  'fiqa:01JPQE6H9CDYE6EMMBAE916YDY',
#  'fiqa:01JPQE6H9CMP2M9TYP03EA6NWD',
#  'fiqa:01JPQE6H9CDPBY5P0WHT9XK7EM',
#  'fiqa:01JPQE6H9C7H2B4RR6YX8KHCZY',
#  'fiqa:01JPQE6H9C6D7PZKVJP9N2DXA9',
#  'fiqa:01JPQE6H9CET0XA8BK0KGGKP21',
#  'fiqa:01JPQE6H9CEN51QRGH1T30M67T',
#  'fiqa:01JPQE6H9CZHX0SDD68MEA3BMQ',
#  'fiqa:01JPQE6H9CQK36ENKF54XNPFRP',
#  'fiqa:01JPQE6H9CPFGCG2SEA8Y5PMMY',
#  'fiqa:01JPQE6H9CVPKPK3C5RA8Z55G5',
#  'fiqa:01JPQE6H9C5V027Y5H6HT8S1RC',
#  'fiqa:01JPQE6H9CGK3N3S0SJ3P9468R',
#  'fiqa:01JPQE6H9CKG514TRY28TH13SK',
#  'fiqa:01JPQE6H9CWAVYBP6DSV9AS4HZ',
#  'fiqa:01JPQE6H9CX1GN24W40EZ65YN0',
#  'fiqa:01JPQE6H9C8P3R4VKKN6RR3BC5',
#  'fiqa:01JPQE6H9CPGVVWFW2XKPQRJ42',
#  'fiqa:01JPQE6H9C3S30C72FZF7EJC1E',
#  'fiqa:01JPQE6H9C5Q71Z6XC2X08MFKF',
#  'fiqa:01JPQE6H9CNJXN0JY2P15M6Q94',
#  'fiqa:01JPQE6H9CFS18A3VV1QE5P2J5',
#  'fiqa:01JPQE6H9CPDP3AH8N2PASQJ4T',
#  'fiqa:01JPQE6H9CECE5XBMCQFPYTSJ9',
#  'fiqa:01JPQE6H9C9R8FZRQ3T40FRFF8',
#  'fiqa:01JPQE6H9CA0YKJR0B2W23TSNC',
#  'fiqa:01JPQE6H9CP8JX1W7VMDC79ENQ',
#  'fiqa:01JPQE6H9DVD5EXMJSZ9V0SFVZ',
#  'fiqa:01JPQE6H9DMDHPFN48WA283NPE',
#  'fiqa:01JPQE6H9D4VH0RG9DSPVRHWQB',
#  'fiqa:01JPQE6H9DVRBGNN9DBW73C3DN',
#  'fiqa:01JPQE6H9DRGFAB9JJPEXY2BTN',
#  'fiqa:01JPQE6H9D2JQGA81NZATD1SX6',
#  'fiqa:01JPQE6H9DDWM1ZAXYKBGXBK6Z',
#  'fiqa:01JPQE6H9D64M7W0JFZQTQATD6',
#  'fiqa:01JPQE6H9DF6EHNYEFC36GH6BH',
#  'fiqa:01JPQE6H9D4W3VHW5D7BER6CPT',
#  'fiqa:01JPQE6H9DKA5RE07PVC5V5C38',
#  'fiqa:01JPQE6H9DDRNYFN7YR31D8FV4',
#  'fiqa:01JPQE6H9DF1B2SR0E3MQQJ7FT',
#  'fiqa:01JPQE6H9DKRSTGB6XH5DV2QAX',
#  'fiqa:01JPQE6H9D00XKDFYQNRNVHK1T',
#  'fiqa:01JPQE6H9DAGDCS6KVADNR68MJ',
#  'fiqa:01JPQE6H9D5AR17SYD7B7YBTMJ',
#  'fiqa:01JPQE6H9DNAR9XRCRHBGZFKB7',
#  'fiqa:01JPQE6H9D75RCZWCB2JGJHW6T',
#  'fiqa:01JPQE6H9D4ZPGSQPE3DM16P3B',
#  'fiqa:01JPQE6H9DH5X50DE4Y6Z93F1R',
#  'fiqa:01JPQE6H9DY84DTRT5WVY38KYS',
#  'fiqa:01JPQE6H9DYSYYT8G37PJQD7GN',
#  'fiqa:01JPQE6H9DQF18ZE1HFK10PZC8',
#  'fiqa:01JPQE6H9D8WDYDM2ARSE8BEV8',
#  'fiqa:01JPQE6H9DWK04CFBGSGR6JMGD',
#  'fiqa:01JPQE6H9DBT5EVWMR5FDG8PY3',
#  'fiqa:01JPQE6H9DAHFFPRJ0PQHJWZ1S',
#  'fiqa:01JPQE6H9DYPZ3S7G5VZ6XSTSN',
#  'fiqa:01JPQE6H9DFCJX6GK9RX00FME8',
#  'fiqa:01JPQE6H9DX2DZN5D5M1HZHWME',
#  'fiqa:01JPQE6H9DXCXGYYTC5FXPT389',
#  'fiqa:01JPQE6H9DBAMK63YV7DMEFYJ3',
#  'fiqa:01JPQE6H9DAGRQ6YPHCZGJWAGV',
#  'fiqa:01JPQE6H9DASTBZTQDD0BEQW0G',
#  'fiqa:01JPQE6H9D000K85X953R98A92',
#  'fiqa:01JPQE6H9DRAMYS1FS8MRP4HC5',
#  'fiqa:01JPQE6H9DE4PQ7Q62N62NEJDE',
#  'fiqa:01JPQE6H9D54CYM2Q6RKQPTTVW',
#  'fiqa:01JPQE6H9DPBS7QJJPNZTN4SR7',
#  'fiqa:01JPQE6H9DGGM3D99ZR2KDM6HZ',
#  'fiqa:01JPQE6H9D809CE95F6JF5W0YT',
#  'fiqa:01JPQE6H9DCHSEKKN2CNQW903Y',
#  'fiqa:01JPQE6H9DZRPZEB2CQR9TCDKE',
#  'fiqa:01JPQE6H9D37RNVZDKMJTF7ECE',
#  'fiqa:01JPQE6H9DSMC2CABCC37CAJQ7',
#  'fiqa:01JPQE6H9D256HHYKCDTX472YG',
#  'fiqa:01JPQE6H9D1DCDM9Q537B94XKD',
#  'fiqa:01JPQE6H9DYT62C1DM3ZQKG1Y3',
#  'fiqa:01JPQE6H9D1ES067ASM7S5TAN3',
#  'fiqa:01JPQE6H9DQMB6ZTSZKMEXA6FF',
#  'fiqa:01JPQE6H9DXFHQ58G1F84PX74C',
#  'fiqa:01JPQE6H9DYA2WWWB28RFZTPGF',
#  'fiqa:01JPQE6H9D1AY3HHE2ZF0RBAN5',
#  'fiqa:01JPQE6H9ESQEYYFDSMQVB2F58',
#  'fiqa:01JPQE6H9EQ13X5734VP0CTMZD',
#  'fiqa:01JPQE6H9E9RWZMWVVCQTFTJ4J',
#  'fiqa:01JPQE6H9EADC9FDES1TFCCSZ1',
#  'fiqa:01JPQE6H9E43ZS7SB41KHVW52E',
#  'fiqa:01JPQE6H9EVX4VAFJ4YBSJAGGV',
#  'fiqa:01JPQE6H9EG47X061Q25XYQZMR',
#  'fiqa:01JPQE6H9ETCH185SMZ5J8VSA6',
#  'fiqa:01JPQE6H9E0HZH6BJXVRCBAAY8',
#  'fiqa:01JPQE6H9EGSESBSN0FA4EH1XK',
#  'fiqa:01JPQE6H9EC3GSAP812V2YEKRE',
#  'fiqa:01JPQE6H9EPBK2V4CJYWX53F87',
#  'fiqa:01JPQE6H9EHS6P309QFSMSNWVS',
#  'fiqa:01JPQE6H9E51YB0TV0YDRWE477',
#  ...]

# %% [markdown]
# ### Review index metrics for loading corpus

# %%
index.info()["num_docs"]
# Out:
# 57638

# %%
float(index.info()["total_indexing_time"]) / (1000) # seconds to index 57k records in redis
# Out:
# 73.919796875

# %% [markdown]
# # Evaluate search approaches
#
# ## Baseline BM25 with bm25s
#
# Pulled from [bm25s](https://github.com/xhluca/bm25s/blob/main/examples/evaluate_on_beir.py)

# %%
import beir.util
from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval.evaluation import EvaluateRetrieval

import bm25s
from bm25s.utils.beir import (
    BASE_URL,
)

def postprocess_results_for_eval(results, scores, query_ids):
    """
    Given the queried results and scores output by BM25S, postprocess them
    to be compatible with BEIR evaluation functions.
    query_ids is a list of query ids in the same order as the results.
    """

    results_record = [
        {"id": qid, "hits": results[i], "scores": list(scores[i])}
        for i, qid in enumerate(query_ids)
    ]

    result_dict_for_eval = {
        res["id"]: {
            docid: float(score) for docid, score in zip(res["hits"], res["scores"])
        }
        for res in results_record
    }

    return result_dict_for_eval

def run_benchmark(dataset, save_dir="datasets"):
    #### Download dataset and unzip the dataset
    data_path = beir.util.download_and_unzip(BASE_URL.format(dataset), save_dir)
    split = "test" if dataset != "msmarco" else "dev"
    corpus, queries, qrels = GenericDataLoader(data_folder=data_path).load(split=split)

    corpus_ids, corpus_lst = [], []
    for key, val in corpus.items():
        corpus_ids.append(key)
        corpus_lst.append(val["title"] + " " + val["text"])
    del corpus

    qids, queries_lst = [], []
    for key, val in queries.items():
        qids.append(key)
        queries_lst.append(val)
    
    corpus_tokens = bm25s.tokenize(
        corpus_lst, leave=False
    )

    del corpus_lst

    query_tokens = bm25s.tokenize(
        queries_lst, leave=False
    )

    model = bm25s.BM25(method="lucene", k1=1.2, b=0.75)
    model.index(corpus_tokens, leave_progress=False)
    
    ############## BENCHMARKING BEIR HERE ##############
    queried_results, queried_scores = model.retrieve(
        query_tokens, corpus=corpus_ids, k=10, n_threads=4
    )

    results_dict = postprocess_results_for_eval(queried_results, queried_scores, qids)
    ndcg, _map, recall, precision = EvaluateRetrieval.evaluate(
        qrels, results_dict, [1, 10]
    )

    print(ndcg)
    print(recall)
    print(precision)
    
    return ndcg, _map, recall, precision, results_dict


bm25s_ndcg, _map, bm25s_recall, bm25s_precision, bm25s_results_dict = run_benchmark("fiqa")  # Change to dataset you want
# Out:
#   0%|          | 0/57638 [00:00<?, ?it/s]
# Split strings:   0%|          | 0/57638 [00:00<?, ?it/s]
# Split strings:   0%|          | 0/648 [00:00<?, ?it/s]
# BM25S Count Tokens:   0%|          | 0/57638 [00:00<?, ?it/s]
# BM25S Compute Scores:   0%|          | 0/57638 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/648 [00:00<?, ?it/s]
# {'NDCG@1': 0.21759, 'NDCG@10': 0.23836}
# {'Recall@1': 0.10704, 'Recall@10': 0.30433}
# {'P@1': 0.21759, 'P@10': 0.06744}

# %% [markdown]
# ## Elasticsearch bm25
#
# [source](https://github.com/beir-cellar/beir/blob/main/examples/retrieval/evaluation/lexical/evaluate_bm25.py)

# %%
from beir import util
from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval.evaluation import EvaluateRetrieval
from beir.retrieval.search.lexical import BM25Search as BM25


#### /print debug information to stdout

#### Download scifact.zip dataset and unzip the dataset
dataset = "fiqa"
url = f"https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{dataset}.zip"
out_dir = "./datasets"
data_path = util.download_and_unzip(url, out_dir)


corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")

#### Lexical Retrieval using Bm25 (Elasticsearch) ####
#### Provide a hostname (localhost) to connect to ES instance
#### Define a new index name or use an already existing one.
#### We use default ES settings for retrieval
#### https://www.elastic.co/

hostname = "localhost:9200"  # localhost
index_name = f"{dataset}"  # fiqa
es_username = "elastic"
es_password = "ZFDOZCxr"


#### Intialize ####
# (1) True - Delete existing index and re-index all documents from scratch
# (2) False - Load existing index
initialize = True  # False

#### Sharding ####
# (1) For datasets with small corpus (datasets ~ < 5k docs) => limit shards = 1
# SciFact is a relatively small dataset! (limit shards to 1)
number_of_shards = 1
model = BM25(
    index_name=index_name,
    hostname=f"http://{es_username}:{es_password}@{hostname}",
    initialize=initialize,
    number_of_shards=number_of_shards,
)

# (2) For datasets with big corpus ==> keep default configuration
# model = BM25(index_name=index_name, hostname=hostname, initialize=initialize)
retriever = EvaluateRetrieval(model)

#### Retrieve dense results (format of results is identical to qrels)
results = retriever.retrieve(corpus, queries)

#### Evaluate your retrieval using NDCG@k, MAP@K ...
# logging.info(f"Retriever evaluation for k in: {retriever.k_values}")
es_ndcg, _map, es_recall, es_precision = retriever.evaluate(qrels, results, retriever.k_values)

# %% [markdown]
# ### Results for ES BM25

# %%
print('NDCG@1: ', es_ndcg['NDCG@1'], 'NDCG@10:', es_ndcg['NDCG@10'])
print('Recall@1: ', es_recall['Recall@1'], 'Recall@10: ', es_recall['Recall@10'])
print('P@1: ', es_precision['P@1'], 'P@10: ', es_precision['P@10'])
# Out:
# NDCG@1:  0.23148 NDCG@10: 0.25364
# Recall@1:  0.11606 Recall@10:  0.3244
# P@1:  0.23148 P@10:  0.07022

# %% [markdown]
# ## Pure BM25 with redis
#
# BM25 is a very popular search technique that powers much of the traditional search engine experience. This type of search works on term frequency so we will also use a `tokenizer` function to remove common "stopwords" and improve the hit rate of our queries.

# %%
from typing import Any, Dict, List
from redis.commands.search.aggregation import AggregateRequest, Desc

from redisvl.query import FilterQuery
from redisvl.query.filter import Text
from redisvl.utils.token_escaper import TokenEscaper

# list of stopwords to filter out noise from query string
# stopwords_en = set([
#     "a", "about", "above", "after", "again", "against", "ain", "all", "am", "an", 
#     "and", "any", "are", "aren", "aren't", "as", "at", "be", "because", "been", 
#     "before", "being", "below", "between", "both", "but", "by", "can", "couldn", 
#     "couldn't", "d", "did", "didn", "didn't", "do", "does", "doesn", "doesn't", 
#     "doing", "don", "don't", "down", "during", "each", "few", "for", "from", 
#     "further", "had", "hadn", "hadn't", "has", "hasn", "hasn't", "have", "haven", 
#     "haven't", "having", "he", "her", "here", "hers", "herself", "him", "himself", 
#     "his", "how", "i", "if", "in", "into", "is", "isn", "isn't", "it", "it's", 
#     "its", "itself", "just", "ll", "m", "ma", "me", "mightn", "mightn't", "more", 
#     "most", "mustn", "mustn't", "my", "myself", "needn", "needn't", "no", "nor", 
#     "not", "now", "o", "of", "off", "on", "once", "only", "or", "other", "our", 
#     "ours", "ourselves", "out", "over", "own", "re", "s", "same", "shan", "shan't", 
#     "she", "she's", "should", "should've", "shouldn", "shouldn't", "so", "some", 
#     "such", "t", "than", "that", "that'll", "the", "their", "theirs", "them", 
#     "themselves", "then", "there", "these", "they", "this", "those", "through", 
#     "to", "too", "under", "until", "up", "ve", "very", "was", "wasn", "wasn't", 
#     "we", "were", "weren", "weren't", "what", "when", "where", "which", "while", 
#     "who", "whom", "why", "will", "with", "won", "won't", "wouldn", "wouldn't", 
#     "y", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", 
#     "yourselves"
# ])

import nltk
out_file  = nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
stopwords_en = set(stopwords)

escaper = TokenEscaper()

def tokenize_and_escape_query(user_query: str) -> str:
    """Convert a raw user query to a redis full text query joined by ORs"""
    tokens = [escaper.escape(token.strip().strip(",").replace("“", "").replace("”", "").lower()) for token in user_query.split()]
    return " | ".join([token for token in tokens if token and token not in stopwords_en])

def bm25_query(text_field: str, user_query: str, num_results: int, scorer="BM25STD") -> FilterQuery:
    """Generate a Redis full-text query given a user query string."""
    return FilterQuery(
        filter_expression=f"~({Text(text_field) % tokenize_and_escape_query(user_query)})",
        num_results=num_results,
        return_fields=["_id", "text", "title"],
        dialect=2,
    ).scorer(scorer).with_scores()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/robert.shelton/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
q = "failed for 8072, What does it mean “sell on ask” , “sell on bid” in stocks?"

tokenize_and_escape_query(q)
# Out:
# 'failed | 8072 | mean | sell | ask | sell | bid | stocks?'

# %% [markdown]
# ### Run queries and format response for evaluation

# %%
# %%capture
redis_res_bm25 = {}

def make_score_dict(res):
    return {rec["_id"]: rec["score"] for rec in res.docs}

for key in queries:
    text_query = queries[key]
    ft_query = bm25_query("text", text_query, 10)
    try:
        res = index.search(ft_query)
        score_dict = make_score_dict(res)
    except Exception as e:
        print(f"failed for {key}, {text_query}")
        score_dict = {}
    redis_res_bm25[key] = score_dict

# %% [markdown]
# ### Results for pure BM25

# %%
redis_bm25_ndcg, _map, redis_bm25_recall, redis_bm25_precision = EvaluateRetrieval.evaluate(
    qrels, redis_res_bm25, [1, 10]
)

print(redis_bm25_ndcg)
print(redis_bm25_recall)
print(redis_bm25_precision)
# Out:
# {'NDCG@1': 0.2037, 'NDCG@10': 0.23083}
# {'Recall@1': 0.1057, 'Recall@10': 0.29653}
# {'P@1': 0.2037, 'P@10': 0.0642}

# %% [markdown]
# ## Pure vector search

# %%
from redisvl.query import VectorQuery

def vector_query(query: str, num_results: int) -> VectorQuery:
    vector = emb_model.embed(query, as_buffer=True)
    
    return VectorQuery(
        vector=vector,
        vector_field_name="vector",
        num_results=num_results,
        return_fields=["_id", "text", "title", "vector_distance"],
    )

# %%
query = vector_query("Something about finance", 10)

res = index.query(query)

res
# Out:
# [{'id': 'fiqa:01JPQE87695T8HG2BKA1G83TN6',
#   'vector_distance': '0.353164196014',
#   '_id': '459638',
#   'text': ' "&gt;""In finance"" What kind of amorphous bullshit is that? There are literally hundreds of different things that can varyingly be termed ""in finance"".    Finally someone says it! Throwing arpimd vague words like finance for describing jobs is a pretty sure-fire indicator that you probably shouldn\'t be entering the industry in the first place."',
#   'title': ''},
#  {'id': 'fiqa:01JPQE8A7V6Q86NXFGPZHPMEEY',
#   'vector_distance': '0.390319168568',
#   '_id': '479752',
#   'text': ' "This is the best tl;dr I could make, [original](https://jacobinmag.com/2017/10/finance-capital-shareholders-profit-market) reduced by 81%. (I\'m a bot) ***** &gt; The term financialization is used all over the place, but it&amp;#039;s usually defined in a pretty circular way: financialization means &amp;quot;More finance,&amp;quot; more things controlled by finance.  &gt; The role of finance in enforcing a certain kind of policy on the state, a certain kind of logic, a certain kind of organization - whether it&amp;#039;s the bond market or whoever else we imagine here - is even more clear-cut.  &gt; To me, that&amp;#039;s a narrower, more specific, and maybe more fruitful way of thinking about financialization than just &amp;quot;There&amp;#039;s more finance.""   ***** [**Extended Summary**](http://np.reddit.com/r/autotldr/comments/78t6so/the_disruptors_jacobin_magazine_via/) | [FAQ](http://np.reddit.com/r/autotldr/comments/31b9fm/faq_autotldr_bot/ ""Version 1.65, ~235206 tl;drs so far."") | [Feedback](http://np.reddit.com/message/compose?to=%23autotldr ""PM\'s and comments are monitored, constructive feedback is welcome."") | *Top* *keywords*: **logic**^#1 **More**^#2 **finance**^#3 **way**^#4 **corporation**^#5"',
#   'title': ''},
#  {'id': 'fiqa:01JPQE8CY3Z2R07FMXTPNQ6B9Y',
#   'vector_distance': '0.392883598804',
#   '_id': '497731',
#   'text': " Can anyone recommend a good textbook for a first course in finance? I'm not studying it, if it's relevant--I'm just a guy who wants a better understanding of the financial sector. I don't know anything anout finance outside a few basic concepts.",
#   'title': ''},
#  {'id': 'fiqa:01JPQE83NRAZWKXJV99RW43V93',
#   'vector_distance': '0.393627583981',
#   '_id': '434733',
#   'text': " Hello,  I'm\u200b very interested in learning money. I used the search function, which led me to Investopedia, and already I'm learning a bunch.  Could you recommend me some introductory reading on finance and economics? I have no education on this subject, and I realise that reading isn't anywhere near having a good formal education, but some knowledge is better than none.  I'm looking to put this knowledge towards understanding what is a an enormous organ of power, and gaining the ability to recognise opportunities and profit.  So yeah, economics and finance, but I will study anything you throw my way, so the more the better. Especially because investments and accounting also seem interesting and useful.  P.S.: I'm European, if this makes a difference in what content will be relevant to me.  Thank you for reading this.",
#   'title': ''},
#  {'id': 'fiqa:01JPQE7PPBFKSX483KBN3AG3XJ',
#   'vector_distance': '0.401096522808',
#   '_id': '335798',
#   'text': ' Try downloading a finance app like yahoo finance. Follow a few stocks, read through the articles - look up terms you don’t understand. Search them on YouTube, Investopedia, - note book recommendations. Learn some economics as well.  Even if you’re not interested in trading, this should help you learn the language enough to get an idea of what’s out there - how money is thought of in different time periods, etc.  Finance can be very opaque when you first dip your feet in. You’ll find you only understand 75% - 25% of what you’re reading but that’s ok just keep looking things up. I guarantee your understanding of what “finance” means will slowly evolve as you keep learning.   Expect to spend maybe a few years to a lifetime figuring this stuff out.',
#   'title': ''},
#  {'id': 'fiqa:01JPQE6XH162571SR2FEE7ERFC',
#   'vector_distance': '0.402551829815',
#   '_id': '133997',
#   'text': " The Khan Academy has a huge series on finance (Sal Khan used to work at a hedge fund before he started his magnum opus): http://www.khanacademy.org/#core-finance  Some are pretty basic stuff, but he does have some interesting commentary and snippets of more interesting topics. They're all very low-commitment and bite-sized.",
#   'title': ''},
#  {'id': 'fiqa:01JPQE8CANK5DGE7V0MEB8JVF3',
#   'vector_distance': '0.415000379086',
#   '_id': '494660',
#   'text': ' "I would recommend ""How to Read a Financial Report : For Managers, Entrepreneurs, Lenders, Lawyers, and Investors"" by John A. Tracy for the following reasons: I also think the book would bridge the gap nicely between a broad understanding of finance and a more serious technical know-how."',
#   'title': ''},
#  {'id': 'fiqa:01JPQE72KMWTWBBH6RCQSPAJKV',
#   'vector_distance': '0.415185272694',
#   '_id': '178061',
#   'text': ' That article was terribly generic and ripe with grammatical errors. A quick Google search yields dozens of much more informative articles. Furthermore, this topic has a fringe relation to finance, and would be a better post in a small business, entrepreneur, or accounting subreddit.',
#   'title': ''},
#  {'id': 'fiqa:01JPQE6H01Y2ZDGSKZJ1W2P779',
#   'vector_distance': '0.415867805481',
#   '_id': '3805',
#   'text': " It's not clear exactly what you're after, but I'd echo /u/avarachen93 and say read the news. I'd focus on the WSJ, Financial Times, and Bloomberg. With the WSJ, read the business and finance section every day. Some articles will explain a topic quite well. Others will assume you already know the underpinnings. If you don't, go search for more on that until you do.  Also, for a more focused look at the financial news you can read some news summaries such as Matt Levine's Money Stuff or NY Time's DealBook.",
#   'title': ''},
#  {'id': 'fiqa:01JPQE6NVY7WEWWY9HAY21F1CA',
#   'vector_distance': '0.421463787556',
#   '_id': '63871',
#   'text': ' "What part of finance does he want to get into? Investments, Equities and trading, derivatives, finance as a whole, corporate finance? Most academic textbooks are ridiculously priced so if he is looking to learn technical skills he might have to look at splashing out or looking elsewhere...  Fundamentals of Corporate Finance 7th is a good one. Covers a lot of the core parts of finance which then extend to all the other areas of finance, starting at the basics of Time Value of Money (though it does gloss over some of the more complex parts). However, it is pretty expensive. This is an academic textbook.  On the non-technical side, there are a number of books with which he could get started. Benjamin Graham\'s ""The Intelligent Investor"" is a popular and affordable one, but it won\'t teach much about the technical side of finance."',
#   'title': ''}]

# %% [markdown]
# ### Run queries

# %%
# %%capture
redis_res_vector = {}

def make_score_dict_vec(res):
    return {rec["_id"]: (2 - float(rec["vector_distance"]) / 2) for rec in res}

for key in queries:
    text_query = queries[key]
    vec_query = vector_query(text_query, 10)
    try:
        res = index.query(vec_query)
        score_dict = make_score_dict_vec(res)
    except Exception as e:
        print(f"failed for {key}, {text_query}")
        score_dict = {}
    redis_res_vector[key] = score_dict

# %% [markdown]
# ### Results for pure vector search

# %%
vec_ndcg, _map, vec_recall, vec_precision = EvaluateRetrieval.evaluate(
    qrels, redis_res_vector, [1, 10]
)

print(vec_ndcg)
print(vec_recall)
print(vec_precision)
# Out:
# 2025-03-24 13:45:09 - For evaluation, we ignore identical query and document ids (default), please explicitly set ``ignore_identical_ids=False`` to ignore this.
# 2025-03-24 13:45:09 -
#
# 2025-03-24 13:45:09 - NDCG@1: 0.3272
# 2025-03-24 13:45:09 - NDCG@10: 0.3447
# 2025-03-24 13:45:09 -
#
# 2025-03-24 13:45:09 - MAP@1: 0.1579
# 2025-03-24 13:45:09 - MAP@10: 0.2715
# 2025-03-24 13:45:09 -
#
# 2025-03-24 13:45:09 - Recall@1: 0.1579
# 2025-03-24 13:45:09 - Recall@10: 0.4113
# 2025-03-24 13:45:09 -
#
# 2025-03-24 13:45:09 - P@1: 0.3272
# 2025-03-24 13:45:09 - P@10: 0.0998
# {'NDCG@1': 0.32716, 'NDCG@10': 0.34469}
# {'Recall@1': 0.15786, 'Recall@10': 0.41133}
# {'P@1': 0.32716, 'P@10': 0.09985}

# %% [markdown]
# ## Weighted combination of BM25 and vector search
#
# Now we will test a linear combination of bm25 scoring with vector search.

# %%
def vector_query_filter(user_query: str, num_results: int, filters = None) -> VectorQuery:
    """Generate a Redis vector query given user query string."""
    vector = emb_model.embed(user_query, as_buffer=True, dtype="float32")
    query = VectorQuery(
        vector=vector,
        vector_field_name="vector",
        num_results=num_results,
        return_fields=["_id", "title", "text"]
    )
    if filters:
        query.set_filter(filters)
    
    return query

def linear_combo(user_query: str, alpha: float, num_results: int = 3) -> AggregateRequest:
    # Add the optional flag, "~", so that this doesn't also act as a strict text filter
    text = f"(~{Text('text') % tokenize_and_escape_query(user_query)})"

    # Build vector query
    query = vector_query_filter(user_query, num_results=num_results, filters=text)
    
    # Build aggregation request
    req = (
        AggregateRequest(query.query_string())
            .scorer("BM25STD")
            .add_scores()
            .apply(cosine_similarity="(2 - @vector_distance)/2", bm25_score="@__score")
            .apply(hybrid_score=f"{1-alpha}*@bm25_score + {alpha}*@cosine_similarity")
            .sort_by(Desc("@hybrid_score"), max=num_results)
            .load("_id", "title", "text", "cosine_similarity", "bm25_score", "hybrid_score")
            .dialect(2)
    )

    query_params = {'vector': query._vector}

    return req, query_params

# %% [markdown]
# ### Run queries

# %%
# %%capture
from redisvl.redis.utils import make_dict, convert_bytes

redis_res_lin_combo = {}

def agg_scores_dict(res):
    if res:
        results = [make_dict(row) for row in convert_bytes(res.rows)]
        return {rec["_id"]: float(rec["hybrid_score"]) for rec in results}

for key in queries:
    text_query = queries[key]
    alpha = 0.8 # weight for cosine similarity vs bm25
    agg_req, query_params = linear_combo(text_query, alpha, 10)
    try:
        res = index.aggregate(agg_req, query_params=query_params)
        score_dict = agg_scores_dict(res)
    except Exception as e:
        print(f"failed for {key}, {text_query}")
        score_dict = {}
    redis_res_lin_combo[key] = score_dict

# %% [markdown]
# ### Results for linear combination of vector and bm25 alpha=0.7

# %%
lin_combo_ndcg, _map, lin_combo_recall, lin_combo_precision = EvaluateRetrieval.evaluate(
    qrels, redis_res_lin_combo, [1, 10]
)

print(lin_combo_ndcg)
print(lin_combo_recall)
print(lin_combo_precision)
# Out:
# 2025-03-24 13:25:21 - For evaluation, we ignore identical query and document ids (default), please explicitly set ``ignore_identical_ids=False`` to ignore this.
# 2025-03-24 13:25:21 -
#
# 2025-03-24 13:25:21 - NDCG@1: 0.2978
# 2025-03-24 13:25:21 - NDCG@10: 0.3297
# 2025-03-24 13:25:21 -
#
# 2025-03-24 13:25:21 - MAP@1: 0.1498
# 2025-03-24 13:25:21 - MAP@10: 0.2512
# 2025-03-24 13:25:21 -
#
# 2025-03-24 13:25:21 - Recall@1: 0.1498
# 2025-03-24 13:25:21 - Recall@10: 0.4149
# 2025-03-24 13:25:21 -
#
# 2025-03-24 13:25:21 - P@1: 0.2978
# 2025-03-24 13:25:21 - P@10: 0.1003
# {'NDCG@1': 0.29784, 'NDCG@10': 0.32969}
# {'Recall@1': 0.14983, 'Recall@10': 0.4149}
# {'P@1': 0.29784, 'P@10': 0.10031}

# %% [markdown]
# ## Client-side fusion with RRF
#
# Instead of relying on document scores like cosine similarity and BM25/TFIDF, we can fetch items and focus on their rank. This rank can be utilized to create a new ranking metric known as [Reciprocal Rank Fusion (RRF)](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf). RRF is powerful because it can handle ranked lists of different length, scores of different scales, and other complexities.

# %%
def fuse_rankings_rrf(*ranked_lists, weights=None, k=60):
    """
    Perform Weighted Reciprocal Rank Fusion on N number of ordered lists.
    """
    item_scores = {}
    
    if weights is None:
        weights = [1.0] * len(ranked_lists)
    else:
        assert len(weights) == len(ranked_lists), "Number of weights must match number of ranked lists"
        assert all(0 <= w <= 1 for w in weights), "Weights must be between 0 and 1"
    
    for ranked_list, weight in zip(ranked_lists, weights):
        for rank, item in enumerate(ranked_list, start=1):
            if item not in item_scores:
                item_scores[item] = 0
            item_scores[item] += weight * (1 / (rank + k))
    
    # Sort items by their weighted RRF scores in descending order
    return sorted(item_scores.items(), key=lambda x: x[1], reverse=True)

# %%
def weighted_rrf(
    user_query: str,
    alpha: float = 0.5,
    num_results: int = 4,
    k: int = 60,
) -> List[Dict[str, Any]]:
    """Implemented client-side RRF after querying from Redis."""
    # Create the vector query
    vector_query = vector_query_filter(user_query, num_results=10)

    # Create the full-text bm25 query
    full_text_query = bm25_query("text", user_query, num_results=10)

    # Run queries individually
    vector_query_results = index.query(vector_query)
    full_text_query_results = index.query(full_text_query)

    # Extract _id from results
    vector_ids = [res["_id"] for res in vector_query_results]
    full_text_ids = [res["_id"] for res in full_text_query_results]

    # Perform weighted RRF
    return fuse_rankings_rrf(vector_ids, full_text_ids, weights=[alpha, 1-alpha], k=k)[:num_results]

# %%
# %%capture
redis_res_w_rrf = {}

def make_score_dict_w_rff(res):
    return {rec[0]: rec[1] for rec in res}

for key in queries:
    text_query = queries[key]
    try:
        w_rff = weighted_rrf(text_query, num_results=10, k=20)
        scores_dict = make_score_dict_w_rff(w_rff)
    except:
        print(f"failed for {key}, {text_query}")
        scores_dict = {}

    redis_res_w_rrf[key] = scores_dict

# %% [markdown]
# # Results for client side fusion with RRF

# %%
w_rrf_ndcg, _map, w_rrf_recall, w_rrf_precision = EvaluateRetrieval.evaluate(
    qrels, redis_res_w_rrf, [1, 10]
)

print(w_rrf_ndcg)
print(w_rrf_recall)
print(w_rrf_precision)
# Out:
# 2025-03-24 13:17:02 - For evaluation, we ignore identical query and document ids (default), please explicitly set ``ignore_identical_ids=False`` to ignore this.
# 2025-03-24 13:17:02 -
#
# 2025-03-24 13:17:02 - NDCG@1: 0.3287
# 2025-03-24 13:17:02 - NDCG@10: 0.3491
# 2025-03-24 13:17:02 -
#
# 2025-03-24 13:17:02 - MAP@1: 0.1614
# 2025-03-24 13:17:02 - MAP@10: 0.2691
# 2025-03-24 13:17:02 -
#
# 2025-03-24 13:17:02 - Recall@1: 0.1614
# 2025-03-24 13:17:02 - Recall@10: 0.4279
# 2025-03-24 13:17:02 -
#
# 2025-03-24 13:17:02 - P@1: 0.3287
# 2025-03-24 13:17:02 - P@10: 0.1000
# {'NDCG@1': 0.3287, 'NDCG@10': 0.34911}
# {'Recall@1': 0.16139, 'Recall@10': 0.42786}
# {'P@1': 0.3287, 'P@10': 0.1}

# %% [markdown]
# ## Client-side reranking
#
# An alternative approach to RRF is to simply use an external reranker to order the final recommendations. RedisVL has built-in integrations to a few popular reranking modules.

# %%
from redisvl.utils.rerank import HFCrossEncoderReranker

# Load the ms marco MiniLM cross encoder model from huggingface
reranker = HFCrossEncoderReranker("cross-encoder/ms-marco-MiniLM-L-6-v2")


def rerank(
    user_query: str,
    num_results: int = 10,
) -> List[Dict[str, Any]]:
    """Rerank the candidates based on the user query with an external model/module."""
    # Create the vector query
    vector_query = vector_query_filter(user_query, num_results=num_results)

    # Create the full-text query
    full_text_query = bm25_query("text", user_query, num_results=num_results)

    # Run queries individually
    vector_query_results = index.query(vector_query)
    full_text_query_results = index.query(full_text_query)

    # Assemble list of potential candidates with their IDs
    candidate_map = {}
    for res in vector_query_results + full_text_query_results:
        candidate = f"Id: {res['_id']}. Text: {res['text']}"
        if candidate not in candidate_map:
            candidate_map[candidate] = res

    # Rerank candidates
    reranked, scores = reranker.rank(
        query=user_query,
        docs=list(candidate_map.keys()),
        limit=num_results,
        return_score=True
    )

    # Fetch full objects for the reranked results
    return [
        (candidate_map[rr['content']]["_id"], score)
        for rr, score in zip(reranked, scores)
    ]

# %%
# %%capture
redis_res_rerank = {}

def make_score_dict_rerank(res):
    return {rec[0]: rec[1] for rec in res}

for key in queries:
    text_query = queries[key]
    try:
        rerank_res = rerank(text_query, num_results=10)
        scores_dict = make_score_dict_rerank(rerank_res)
    except:
        print(f"failed for {key}, {text_query}")
        scores_dict = {}

    redis_res_rerank[key] = scores_dict

# %%
rerank_ndcg, _map, rerank_recall, rerank_precision = EvaluateRetrieval.evaluate(
    qrels, redis_res_rerank, [1, 10], ignore_identical_ids=False
)

print(rerank_ndcg)
print(rerank_recall)
print(rerank_precision)
# Out:
# 2025-03-24 13:47:44 -
#
# 2025-03-24 13:47:44 - NDCG@1: 0.2747
# 2025-03-24 13:47:44 - NDCG@10: 0.3281
# 2025-03-24 13:47:44 -
#
# 2025-03-24 13:47:44 - MAP@1: 0.1349
# 2025-03-24 13:47:44 - MAP@10: 0.2443
# 2025-03-24 13:47:44 -
#
# 2025-03-24 13:47:44 - Recall@1: 0.1349
# 2025-03-24 13:47:44 - Recall@10: 0.4397
# 2025-03-24 13:47:44 -
#
# 2025-03-24 13:47:44 - P@1: 0.2747
# 2025-03-24 13:47:44 - P@10: 0.1031
# {'NDCG@1': 0.27469, 'NDCG@10': 0.32813}
# {'Recall@1': 0.13487, 'Recall@10': 0.43971}
# {'P@1': 0.27469, 'P@10': 0.10309}

# %%
import pandas as pd

res_data = {
    "Model": ["BM25S", "es_bm25", "redis_BM25", "redis_vector", "lin_combo", "weighted_rrf", "rerank"],
    "NDCG@1": [bm25s_ndcg['NDCG@1'], es_ndcg['NDCG@1'], redis_bm25_ndcg['NDCG@1'], vec_ndcg['NDCG@1'], lin_combo_ndcg['NDCG@1'], w_rrf_ndcg['NDCG@1'], rerank_ndcg['NDCG@1']],
    "NDCG@10": [bm25s_ndcg['NDCG@10'], es_ndcg['NDCG@10'], redis_bm25_ndcg['NDCG@10'], vec_ndcg['NDCG@10'], lin_combo_ndcg['NDCG@10'], w_rrf_ndcg['NDCG@10'], rerank_ndcg['NDCG@10']],
    "Recall@1": [bm25s_recall['Recall@1'], es_recall['Recall@1'], redis_bm25_recall['Recall@1'], vec_recall['Recall@1'], lin_combo_recall['Recall@1'], w_rrf_recall['Recall@1'], rerank_recall['Recall@1']],
    "Recall@10": [bm25s_recall['Recall@10'], es_recall['Recall@10'], redis_bm25_recall['Recall@10'], vec_recall['Recall@10'], lin_combo_recall['Recall@10'], w_rrf_recall['Recall@10'], rerank_recall['Recall@10']],
    "Precision@1": [bm25s_precision['P@1'], es_precision['P@1'], redis_bm25_precision['P@1'], vec_precision['P@1'], lin_combo_precision['P@1'], w_rrf_precision['P@1'], rerank_precision['P@1']],
    "Precision@10": [bm25s_precision['P@10'], es_precision['P@10'], redis_bm25_precision['P@10'], vec_precision['P@10'], lin_combo_precision['P@10'], w_rrf_precision['P@10'], rerank_precision['P@10']]
}

df = pd.DataFrame(res_data)

# %%
df[["Model", "Recall@10", "NDCG@10", "Precision@1"]].sort_values(by=["Recall@10"], ascending=False).reset_index(drop=True)
# Out:
#           Model  Recall@10  NDCG@10  Precision@1
# 0        rerank    0.43971  0.32813      0.27469
# 1  weighted_rrf    0.42786  0.34911      0.32870
# 2     lin_combo    0.41490  0.32969      0.29784
# 3  redis_vector    0.41133  0.34469      0.32716
# 4       es_bm25    0.32440  0.25364      0.23148
# 5         BM25S    0.30433  0.23836      0.21759
# 6    redis_BM25    0.29653  0.23083      0.20370

# %%
df.to_csv("fiqa_results.csv", index=False)
