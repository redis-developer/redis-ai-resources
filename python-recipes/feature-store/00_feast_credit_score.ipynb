# %% [markdown]
# ![Redis](https://redis.io/wp-content/uploads/2024/04/Logotype.svg?auto=webp&quality=85,75&width=120)
#
# # Redis Online Feature Store with Feast
#
# In this recipe, we will learn all about [Feature Stores](https://redis.io/solutions/feature-stores/) with **Redis** and **Feast**. This guide is an adaptation of the [Feast Tutorial](https://docs.feast.dev/tutorials/tutorials-overview/real-time-credit-scoring-on-aws) that uses [Redis as the online feature store](https://docs.feast.dev/reference/online-stores/redis).

# %% [markdown]
# ## Let's Begin!
# <a href="https://colab.research.google.com/github/redis-developer/redis-ai-resources/blob/feat/RAAE-447/feature-store-recipe/python-recipes/feature-store/01_feast_credit_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Environment Setup
#
# ### Install Python Dependencies

# %%
# !pip install -q feast['redis']==0.42.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 11.8 MB/s eta 0:00:00

# %% [markdown]
# ### Install Redis Stack
#
# In this recipe, **Redis** will be used to store and fetch ML model features through Feast. **We need to make sure we have a Redis instance available.**

# %% [markdown]
# #### For Colab
# Use the shell script below to download, extract, and install [Redis Stack](https://redis.io/docs/getting-started/install-stack/) directly from the Redis package archive.

# %%
# NBVAL_SKIP
# %%sh
curl -fsSL https://packages.redis.io/gpg | sudo gpg --dearmor -o /usr/share/keyrings/redis-archive-keyring.gpg
echo "deb [signed-by=/usr/share/keyrings/redis-archive-keyring.gpg] https://packages.redis.io/deb $(lsb_release -cs) main" | sudo tee /etc/apt/sources.list.d/redis.list
sudo apt-get update  > /dev/null 2>&1
sudo apt-get install redis-stack-server  > /dev/null 2>&1
redis-stack-server --daemonize yes
# Out:
# deb [signed-by=/usr/share/keyrings/redis-archive-keyring.gpg] https://packages.redis.io/deb jammy main
# Starting redis-stack-server, database path /var/lib/redis-stack
# gpg: cannot open '/dev/tty': No such device or address
# curl: (23) Failed writing body

# %% [markdown]
# #### For Alternative Environments
# There are many ways to get the necessary redis-stack instance running
# 1. On cloud, deploy a [FREE instance of Redis in the cloud](https://redis.io/cloud/). Or, if you have your
# own version of Redis Enterprise running, that works too!
# 2. Per OS, [see the docs](https://redis.io/docs/latest/operate/oss_and_stack/install/install-stack/)
# 3. With docker:
#
#     ```bash
#     docker run -d --name redis-stack-server -p 6379:6379 redis/redis-stack-server:latest
#     ```

# %% [markdown]
# ### Define the Redis Connection URL
#
# By default this notebook connects to the local instance of Redis Stack. **If you have your own Redis Enterprise instance** - replace `REDIS_PASSWORD`, `REDIS_HOST` and `REDIS_PORT` values with your own.

# %%
import os
import warnings

REDIS_HOST = os.getenv("REDIS_HOST", "localhost")
REDIS_PORT = os.getenv("REDIS_PORT", "6379")
REDIS_PASSWORD = os.getenv("REDIS_PASSWORD", "")

# Replace values above with your own if using Redis Cloud instance
#REDIS_HOST="redis-18374.c253.us-central1-1.gce.cloud.redislabs.com"
#REDIS_PORT=18374
#REDIS_PASSWORD="1TNxTEdYRDgIDKM2gDfasupCADXXXX"

# If SSL is enabled on the endpoint, use rediss:// as the URL prefix
REDIS_URL = f"redis://:{REDIS_PASSWORD}@{REDIS_HOST}:{REDIS_PORT}"

# See https://docs.feast.dev/reference/online-stores/redis for details on Feast connection to Redis
REDIS_URL_FEAST = f"{REDIS_HOST}:{REDIS_PORT},ssl=false,password={REDIS_PASSWORD}"

# %% [markdown]
# ## Load features dataset
#
# Below we will make a `creditscore/` directory which will be the home of our Feast repo. We'll create and store additional files there down the road. For now we are loading dataset files into `creditscore/data`.

# %%
# %%bash
# mkdir creditscore
# mkdir creditscore/data
# wget https://github.com/antonum/feast-redis/raw/refs/heads/main/creditscore/data/credit_history.parquet -q -P creditscore/data
# wget https://github.com/antonum/feast-redis/raw/refs/heads/main/creditscore/data/zipcode_table.parquet -q -P creditscore/data
# wget https://github.com/antonum/feast-redis/raw/refs/heads/main/creditscore/data/loan_table.parquet -q -P creditscore/data
# Out:
# mkdir: cannot create directory ‘creditscore’: File exists
# mkdir: cannot create directory ‘creditscore/data’: File exists

# %% [markdown]
# ### Creating feature_store.yaml
#
# `feature_store.yaml` is used to configure a feature store with Feast. The file must be located at the root of a feature repository `creditscore/`.
#
# See [Redis | Feast Documentation](https://docs.feast.dev/reference/online-stores/redis) for the details of configuring Redis as an online store.

# %%
feature_store_config = \
f"""project: creditscore
registry: data/registry.db
provider: local
online_store:
    type: redis
    connection_string: {REDIS_URL_FEAST}
entity_key_serialization_version: 2
"""

with open('creditscore/feature_store.yaml', "w") as file:
    file.write(feature_store_config)

# %%
# Print our feature_store.yaml
! cat creditscore/feature_store.yaml
# Out:
# project: creditscore
# registry: data/registry.db
# provider: local
# online_store:
#     type: redis
#     connection_string: localhost:6379,ssl=false,password=
# entity_key_serialization_version: 2

# %% [markdown]
# ### Feature Definitions
#
# A feature repository can also contain one or more Python files that contain feature definitions.

# %%
# %%writefile creditscore/features.py

from datetime import timedelta

from feast import (
    Entity,
    Field,
    FeatureView,
    ValueType,
    FileSource
  )
from feast.types import Float32, Int64, String


# Feature Definitions

## Zipcode Features
zipcode = Entity(
    name="zipcode",
    value_type=ValueType.STRING
)
zipcode_source = FileSource(
    path="data/zipcode_table.parquet",
    timestamp_field="event_timestamp",
    #event_timestamp_column="event_timestamp",
    created_timestamp_column="created_timestamp",
)
zipcode_features = FeatureView(
    name="zipcode_features",
    entities=[zipcode],
    ttl=timedelta(days=3650),
    schema=[
        Field(name="city", dtype=String),
        Field(name="state", dtype=String),
        Field(name="location_type", dtype=String),
        Field(name="tax_returns_filed", dtype=Int64),
        Field(name="population", dtype=Int64),
        Field(name="total_wages", dtype=Int64),
    ],
    source=zipcode_source,
)


## Credit History Features
dob_ssn = Entity(
    name="dob_ssn",
    description="Date of birth and last four digits of social security number",
    value_type=ValueType.STRING
)
credit_history_source = FileSource(
    path="data/credit_history.parquet",
    timestamp_field="event_timestamp",
    #event_timestamp_column="event_timestamp",
    created_timestamp_column="created_timestamp",

)
credit_history = FeatureView(
    name="credit_history",
    entities=[dob_ssn],
    ttl=timedelta(days=3650),
    schema=[
        Field(name="dob_ssn", dtype=String),  # Add entity column for dob_ssn
        Field(name="credit_card_due", dtype=Int64),
        Field(name="mortgage_due", dtype=Int64),
        Field(name="student_loan_due", dtype=Int64),
        Field(name="vehicle_loan_due", dtype=Int64),
        Field(name="hard_pulls", dtype=Int64),
        Field(name="missed_payments_2y", dtype=Int64),
        Field(name="missed_payments_1y", dtype=Int64),
        Field(name="missed_payments_6m", dtype=Int64),
        Field(name="bankruptcies", dtype=Int64),
    ],
    source=credit_history_source,
)
# Out:
# Overwriting creditscore/features.py

# %% [markdown]
# ### Create Feast repository

# %%
# %cd creditscore/
# !feast apply
# Out:
# /content/creditscore
# No project found in the repository. Using project name creditscore defined in feature_store.yaml
# Applying changes for project creditscore
# Deploying infrastructure for credit_history
# Deploying infrastructure for zipcode_features

# %% [markdown]
# ### Materialize features into Redis
#
# Load data from feature views (parquet files) into the online store (Redis). Use `feast materialize-incremental` to update online store with changes since the last `materialize` call.

# %%
warnings.simplefilter("ignore", DeprecationWarning)

# !feast materialize-incremental 2025-01-24T16:57:10
# %cd ..
# Out:
# Materializing 2 feature views to 2025-01-24 16:57:10+00:00 into the redis online store.
#
# credit_history from 2025-01-24 16:57:10+00:00 to 2025-01-24 16:57:10+00:00:
# 0it [00:00, ?it/s]
# zipcode_features from 2025-01-24 16:57:10+00:00 to 2025-01-24 16:57:10+00:00:
# 0it [00:00, ?it/s]
# /content

# %% [markdown]
# ## Retreive feature vector from the Redis Online Store
#
# `feast apply` and `feast materialize` initialized our feature store, so now we can request features from the Redis online store with `store.get_online_features()` call.

# %%
from feast import FeatureStore
warnings.simplefilter("ignore", DeprecationWarning)


store = FeatureStore(repo_path="creditscore/")
feast_features = [
        "zipcode_features:city",
        "zipcode_features:state",
        "zipcode_features:location_type",
        "zipcode_features:tax_returns_filed",
        "zipcode_features:population",
        "zipcode_features:total_wages",
        "credit_history:credit_card_due",
        "credit_history:mortgage_due",
        "credit_history:student_loan_due",
        "credit_history:vehicle_loan_due",
        "credit_history:hard_pulls",
        "credit_history:missed_payments_2y",
        "credit_history:missed_payments_1y",
        "credit_history:missed_payments_6m",
        "credit_history:bankruptcies",
    ]
zipcode = "76104"
dob_ssn = "19630621_4278"

feature_vector = store.get_online_features(
    features = feast_features,
    entity_rows = [{"zipcode": zipcode, "dob_ssn": dob_ssn}]
)
feature_vector.to_dict()
# Out:
# {'zipcode': ['76104'],
#  'dob_ssn': ['19630621_4278'],
#  'tax_returns_filed': [6058],
#  'state': ['TX'],
#  'total_wages': [142325465],
#  'city': ['FORT WORTH'],
#  'population': [10534],
#  'location_type': ['PRIMARY'],
#  'hard_pulls': [1],
#  'missed_payments_2y': [0],
#  'missed_payments_1y': [0],
#  'student_loan_due': [44375],
#  'vehicle_loan_due': [11506],
#  'credit_card_due': [3343],
#  'bankruptcies': [0],
#  'mortgage_due': [378847],
#  'missed_payments_6m': [0]}

# %% [markdown]
# ## Examine source data
#
# `credit_history.parquet` and `zipcode_table.parquet` contains data that would be exposed by our featurestoe as both online and offline features.  `loan_table.parquet` is used only to train the model and contains historical loan request submissions and target value as approve/deny in `loan_status`.

# %%
import pandas as pd

pd.read_parquet("creditscore/data/credit_history.parquet")

# zipcode_table.parquet
# loan_table.parquet
# Out:
#                    event_timestamp        dob_ssn  credit_card_due  \
# 0       2020-04-26 18:01:04.746575  19530219_5179             8419
# 1       2020-04-26 18:01:04.746575  19781116_7723             2944
# 2       2020-04-26 18:01:04.746575  19931128_5771              833
# 3       2020-04-26 18:01:04.746575  19500806_6783             5936
# 4       2020-04-26 18:01:04.746575  19620322_7692             1575
# ...                            ...            ...              ...
# 2033293 2021-08-29 18:01:04.746575  19621030_8837             9045
# 2033294 2021-08-29 18:01:04.746575  19810914_5886             5065
# 2033295 2021-08-29 18:01:04.746575  19491025_8061              738
# 2033296 2021-08-29 18:01:04.746575  19751125_4615             3443
# 2033297 2021-08-29 18:01:04.746575  19960703_3449             1928
#
#          mortgage_due  student_loan_due  vehicle_loan_due  hard_pulls  \
# 0               91803             22328             15078           0
# 1              741165              2515             28605           0
# 2              976522             33000             21733           9
# 3             1553523             48955             26219           1
# 4             1067381              9501             15814           1
# ...               ...               ...               ...         ...
# 2033293       1106144             25760             13826           8
# 2033294       1376873             20594             13948           8
# 2033295        273532             24113             15902          10
# 2033296       1534792             43133             16294           4
# 2033297       1197324             24208              4691           1
#
#          missed_payments_2y  missed_payments_1y  missed_payments_6m  \
# 0                         1                   0                   0
# 1                         3                   3                   1
# 2                         7                   0                   0
# 3                         0                   0                   0
# 4                         1                   0                   0
# ...                     ...                 ...                 ...
# 2033293                   5                   2                   1
# 2033294                   5                   1                   1
# 2033295                   1                   2                   1
# 2033296                   6                   2                   1
# 2033297                   4                   0                   1
#
#          bankruptcies          created_timestamp
# 0                   0 2020-04-26 18:01:04.746575
# 1                   0 2020-04-26 18:01:04.746575
# 2                   0 2020-04-26 18:01:04.746575
# 3                   0 2020-04-26 18:01:04.746575
# 4                   0 2020-04-26 18:01:04.746575
# ...               ...                        ...
# 2033293             0 2021-08-29 18:01:04.746575
# 2033294             0 2021-08-29 18:01:04.746575
# 2033295             0 2021-08-29 18:01:04.746575
# 2033296             0 2021-08-29 18:01:04.746575
# 2033297             0 2021-08-29 18:01:04.746575
#
# [2033298 rows x 12 columns]

# %% [markdown]
# ## Machine Learning Model Training
#
# While our feature store at this point already complete, let's put it to a good use and introduce a `LoadRequestModel` that we will train, using `get_historical_features()` and use to make predictions with `get_online_features()`

# %%
from pathlib import Path

import feast
import joblib
import pandas as pd

from sklearn import tree
from sklearn.exceptions import NotFittedError
from sklearn.preprocessing import OrdinalEncoder
from sklearn.utils.validation import check_is_fitted
warnings.simplefilter("ignore", DeprecationWarning)


class LoadRequestModel:
    """
    ML model to classify whether a person should
    get approved or rejected for a loan based on a variety of
    input factors.
    """
    categorical_features = [
        "person_home_ownership",
        "loan_intent",
        "city",
        "state",
        "location_type",
    ]

    feast_features = [
        "zipcode_features:city",
        "zipcode_features:state",
        "zipcode_features:location_type",
        "zipcode_features:tax_returns_filed",
        "zipcode_features:population",
        "zipcode_features:total_wages",
        "credit_history:credit_card_due",
        "credit_history:mortgage_due",
        "credit_history:student_loan_due",
        "credit_history:vehicle_loan_due",
        "credit_history:hard_pulls",
        "credit_history:missed_payments_2y",
        "credit_history:missed_payments_1y",
        "credit_history:missed_payments_6m",
        "credit_history:bankruptcies",
    ]

    target = "loan_status"
    model_filename = "model.bin"
    encoder_filename = "encoder.bin"

    def __init__(self,secret=""):
        # Load model
        if Path(self.model_filename).exists():
            self.classifier = joblib.load(self.model_filename)
        else:
            self.classifier = tree.DecisionTreeClassifier()

        # Load ordinal encoder
        if Path(self.encoder_filename).exists():
            self.encoder = joblib.load(self.encoder_filename)
        else:
            self.encoder = OrdinalEncoder()

        # Set up feature store
        self.fs = feast.FeatureStore(repo_path="creditscore/")
        #if secret and (":" in secret):
        #    self.fs.config.online_store.connection_string=secret

    def train(self, loans):
        train_X, train_Y = self._get_training_features(loans)

        self.classifier.fit(train_X[sorted(train_X)], train_Y)
        joblib.dump(self.classifier, self.model_filename)

    def _get_training_features(self, loans):
        training_df = self.fs.get_historical_features(
            entity_df=loans, features=self.feast_features
        ).to_df()

        self._fit_ordinal_encoder(training_df)
        self._apply_ordinal_encoding(training_df)
        #print(training_df.head())
        train_X = training_df[
            training_df.columns.drop(self.target)
            .drop("event_timestamp")
            .drop("created_timestamp__")
            .drop("loan_id")
            .drop("zipcode")
            .drop("dob_ssn")
        ]
        train_X = train_X.reindex(sorted(train_X.columns), axis=1)
        train_Y = training_df.loc[:, self.target]

        return train_X, train_Y

    def _fit_ordinal_encoder(self, requests):
        self.encoder.fit(requests[self.categorical_features])
        joblib.dump(self.encoder, self.encoder_filename)

    def _apply_ordinal_encoding(self, requests):
        requests[self.categorical_features] = self.encoder.transform(
            requests[self.categorical_features]
        )

    def predict(self, request):
        # Get online features from Feast
        feature_vector = self._get_online_features_from_feast(request)

        # Join features to request features
        features = request.copy()
        features.update(feature_vector)
        features_df = pd.DataFrame.from_dict(features)

        # Apply ordinal encoding to categorical features
        self._apply_ordinal_encoding(features_df)

        # Sort columns
        features_df = features_df.reindex(sorted(features_df.columns), axis=1)

        # Drop unnecessary columns
        features_df = features_df[features_df.columns.drop("zipcode").drop("dob_ssn")]

        # Make prediction
        features_df["prediction"] = self.classifier.predict(features_df)

        # return result of credit scoring
        return features_df["prediction"].iloc[0]

    def _get_online_features_from_feast(self, request):
        zipcode = request["zipcode"][0]
        dob_ssn = request["dob_ssn"][0]

        return self.fs.get_online_features(
            entity_rows=[{"zipcode": zipcode, "dob_ssn": dob_ssn}],
            features=self.feast_features,
        ).to_dict()

    def is_model_trained(self):
        try:
            check_is_fitted(self.classifier, "tree_")
        except NotFittedError:
            return False
        return True

# %% [markdown]
# ## Initialize the model
#
# Now we need to train the model and make a sample prediction. After training is completed you'll see `model.bin` and `encoder.bin` files in the filesystem.

# %%
# Create model
model = LoadRequestModel()

# Train model (using Parquet for zipcode and credit history features)
if not model.is_model_trained():
    print("Model not trained. Performing training.")
    # Get historic loan data
    loans = pd.read_parquet("creditscore/data/loan_table.parquet")
    model.train(loans)

# %% [markdown]
# ### Make a Loan Request
#
# We will now use our trained ML model and feature store to predict whether or not you would get a loan.
#
# While making a loan request, make sure that `dob_ssn` and `zipcode` values do exist in the source datasets. You can examine source datasets with `pd.read_parquet("creditscore/data/credit_history.parquet")`

# %%
import ipywidgets as widgets

# initialize loan request with sample data
loan_request = {
    "zipcode": [76104],
    "dob_ssn": ["19630621_4278"],
    "person_age": [63],
    "person_income": [159000],
    "person_home_ownership": ["RENT"],
    "person_emp_length": [123.0],
    "loan_intent": ["PERSONAL"],
    "loan_amnt": [5000],
    "loan_int_rate": [16.02],
}


slider_income = widgets.IntSlider(loan_request["person_income"][0], max=1000000, min=0, description="Income: ")
slider_amount = widgets.IntSlider(loan_request["loan_amnt"][0], max=1000000, min=0, description="Loan Amount: ")
slider_int_rate = widgets.IntSlider(loan_request["loan_int_rate"][0], max=90, min=1, description="Interest Rate: ")

print("Select amounts below:")
display(slider_income, slider_amount, slider_int_rate)
# Out:
# Select amounts below:
# IntSlider(value=159000, description='Income: ', max=1000000)
# IntSlider(value=5000, description='Loan Amount: ', max=1000000)
# IntSlider(value=16, description='Interest Rate: ', max=90, min=1)

# %%
loan_request["person_income"] = [slider_income.value]
loan_request["loan_amnt"] = [slider_amount.value]
loan_request["loan_int_rate"] = [slider_int_rate.value]


# Make online prediction (using Redis for retrieving online features)
result = model.predict(loan_request)

if result == 0:
    print("Loan approved!")
elif result == 1:
    print("Loan rejected!")

warnings.simplefilter("ignore", DeprecationWarning)
# Out:
# Loan rejected!

# %% [markdown]
# Let's inspect an individual loan request payload.

# %%
warnings.simplefilter("ignore", DeprecationWarning)

loan_request_df = pd.DataFrame.from_dict(loan_request)
loan_request_df.transpose()
# Out:
#                                    0
# zipcode                        76104
# dob_ssn                19630621_4278
# person_age                        63
# person_income                 159000
# person_home_ownership           RENT
# person_emp_length              123.0
# loan_intent                 PERSONAL
# loan_amnt                       5000
# loan_int_rate                     16

# %% [markdown]
# Let's inspect the feature store features pulled from Redis.

# %%
warnings.simplefilter("ignore", DeprecationWarning)

feature_vector = model._get_online_features_from_feast(loan_request)
feature_vector_df=pd.DataFrame.from_dict(feature_vector)
feature_vector_df.transpose()
# Out:
#                                 0
# zipcode                     76104
# dob_ssn             19630621_4278
# tax_returns_filed            6058
# state                          TX
# total_wages             142325465
# city                   FORT WORTH
# population                  10534
# location_type             PRIMARY
# hard_pulls                      1
# missed_payments_2y              0
# missed_payments_1y              0
# student_loan_due            44375
# vehicle_loan_due            11506
# credit_card_due              3343
# bankruptcies                    0
# mortgage_due               378847
# missed_payments_6m              0

# %% [markdown]
# Join the features to see the entire input sent to the credit prediction model.

# %%
features = loan_request.copy()
features.update(feature_vector)
features_df = pd.DataFrame.from_dict(features)
features_df.transpose()
# Out:
#                                    0
# zipcode                        76104
# dob_ssn                19630621_4278
# person_age                        63
# person_income                 159000
# person_home_ownership           RENT
# person_emp_length              123.0
# loan_intent                 PERSONAL
# loan_amnt                       5000
# loan_int_rate                     16
# tax_returns_filed               6058
# state                             TX
# total_wages                142325465
# city                      FORT WORTH
# population                     10534
# location_type                PRIMARY
# hard_pulls                         1
# missed_payments_2y                 0
# missed_payments_1y                 0
# student_loan_due               44375
# vehicle_loan_due               11506
# credit_card_due                 3343
# bankruptcies                       0
# mortgage_due                  378847
# missed_payments_6m                 0

# %%
result = model.predict(loan_request)

if result == 0:
    print("Loan approved!")
elif result == 1:
    print("Loan rejected!")
# Out:
# Loan rejected!

# %% [markdown]
# ## Benchmarking
#
# The key advantage of Redis as a Online feature store is it's ability to very quickly retreive features on request. Below, we'll retreive the same data from Online store (Redis) and from the Offline store (parquet) and measure execution time.

# %%
store = FeatureStore(repo_path="creditscore/")
feast_features = [
        "zipcode_features:city",
        "zipcode_features:state",
        "zipcode_features:location_type",
        "zipcode_features:tax_returns_filed",
        "zipcode_features:population",
        "zipcode_features:total_wages",
        "credit_history:credit_card_due",
        "credit_history:mortgage_due",
        "credit_history:student_loan_due",
        "credit_history:vehicle_loan_due",
        "credit_history:hard_pulls",
        "credit_history:missed_payments_2y",
        "credit_history:missed_payments_1y",
        "credit_history:missed_payments_6m",
        "credit_history:bankruptcies",
    ]
zipcode = "76104"
dob_ssn = "19630621_4278"

entity_rows=[{"zipcode": zipcode, "dob_ssn": dob_ssn}]
entity_rows_df=pd.DataFrame(entity_rows)
entity_rows_df["event_timestamp"]=pd.to_datetime("2020-04-26 18:01:04.746575")
entity_rows_df['zipcode'] = entity_rows_df['zipcode'].astype(int)

# %% [markdown]
# Online feature store retrieval benchmark:

# %%
# %%timeit

online_features = store.get_online_features(
    features = feast_features,
    entity_rows = entity_rows
)
# Out:
# 15.5 ms ± 772 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Offline feature store retrieval benchmark:

# %%
# %%timeit

offline_features= store.get_historical_features(
    entity_df = entity_rows_df,
    features = feast_features
).to_df()
# Out:
# 3.77 s ± 449 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# >Note: That's more than a 100x difference. (typically)

# %%
# retreive sample of keys from redis
from redis import Redis

redis_client = Redis.from_url(REDIS_URL)
redis_client.keys()
# Out:
# [b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00y\x14\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019770705_9126creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019991125_5865creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019861118_3193creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020011102_9929creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00(G\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019860122_3218creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019991027_1238creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0f\xb9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0070744creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x01%\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0034948creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019660219_8193creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xa2\x98\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0089046creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x001]\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x98\xc0\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00h\x00\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0053585creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0c\xd3\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0077574creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc6\xac\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019470204_3321creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x82\xe1\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0070122creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb2\x13\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x15\xad\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x17\xcc\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0089515creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019830625_4163creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019790516_3252creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0089042creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00JX\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019651127_6295creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019920123_2707creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019580304_8660creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x008\xef\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb4\xbf\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028687creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019990318_2774creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0092126creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0052042creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xad\xe9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xdel\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0044455creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019861117_3655creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019771012_9219creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019840823_8345creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xaas\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0052043creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019800903_8814creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0023092creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019460903_3674creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb7\x89\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0046531creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc7\xaa\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0092203creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9e\x99\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0089011creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0033938creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0050028creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00f\xb4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe9\xea\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x004858creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9f\xa2\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc9\xaf\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0030521creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0032129creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xfa\xb0\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019860904_9391creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0043451creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0054177creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\r\x0f\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019990614_9610creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019540304_8677creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0045732creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0039668creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019470905_9007creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019600712_1774creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x006069creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019670920_6582creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019620313_3558creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019490901_7867creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0093446creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0098638creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd8\x7f\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8bo\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0043345creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x06g\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0059841creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xf0t\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xbf\x88\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0098262creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019530911_9817creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0035677creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xaa\x98\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019911221_4965creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x02\x90\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0056241creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019911018_8427creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0044129creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x18\x0b\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019501119_7172creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xde*\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019840127_1926creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xce\x7f\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0029745creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00P5\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00DN\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019680126_8252creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xef\x16\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0071496creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019820430_9433creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xec\xea\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019750610_6829creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019940507_3363creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0091203creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0084767creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00C\xcb\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x12\x17\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0083554creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0041166creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019560117_2943creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xfb8\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0024382creditscore',
#  b"\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe6'\x01\x00\x00\x00\x00\x00creditscore",
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0023153creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x002740creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019680124_8351creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019541020_8086creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019640210_7513creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xec\xde\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019561002_2755creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019490308_3953creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc2h\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0093121creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019880218_7635creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019810709_5588creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0012182creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0049643creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0080501creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8f\xef\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x80\x12\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0030514creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00X\x00\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019860427_3099creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019750709_6101creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9c>\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019831123_9073creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0035054creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x002Q\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x1a\xb4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe4\x94\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0c$\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019540512_6760creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019781128_5968creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0097630creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0053051creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x002763creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x80\x8e\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0061036creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd5W\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0046510creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0012210creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe2N\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x15e\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00p\x0b\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0095668creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0060680creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0036123creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0085631creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00]i\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019580424_3321creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00(\x80\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x001090creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xfe\x0f\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019571003_4906creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0065808creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00V\x80\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0031554creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x88R\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019840318_6955creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00H\x96\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019531111_3796creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019911213_5683creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0066614creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0055355creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019760411_1341creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019861015_7348creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0036540creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019920517_2845creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x006084creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019920920_8806creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0062822creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0e\xb8\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x19-\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x04+\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0058622creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00hf\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0063552creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019570305_9399creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb9F\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019571110_1139creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019510714_4360creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0043608creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019521204_1131creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0054124creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0044880creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9dS\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x80;\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xcd\x17\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd2\xd4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019630823_9391creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00!\x12\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019861014_7704creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00,\xf1\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x94%\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0092506creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xf3\x80\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019790723_1087creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0023883creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x97\x05\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019590921_6310creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9c\xb9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019970203_9000creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x86a\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8a\xd8\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\\o\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0055104creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xab/\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0074630creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0092548creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00^z\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x94\x1d\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019770425_7351creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x01`\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019730701_5230creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0023944creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019940326_2142creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe7\x81\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019910201_5148creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019630623_6390creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0032063creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019830803_1461creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x1eJ\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00m\xc9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0071802creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019501025_2417creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0097124creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019821113_7513creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0031705creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x192\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0099711creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019740805_3988creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe3a\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xbd2\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0043452creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x92\xdf\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x003243creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019711108_2410creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00}\x82\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00!\xe4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00,\xd7\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8b\x94\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00: \x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xff\x7f\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019850523_9075creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0038548creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\\\xb7\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0050251creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019560313_5814creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00i\x84\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd7\x0c\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019751202_7867creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019480817_4555creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019570330_2085creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028806creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0015742creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019740909_9029creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019780508_1342creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0093722creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019960924_1934creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0032909creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0033763creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019511117_6957creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020000823_8882creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019650103_9417creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019550301_8339creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0054974creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019690119_1621creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0033960creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xcf-\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb5_\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00Q\x8f\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00v\xd5\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0012529creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019821220_3203creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00Lc\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0080005creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0013141creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0082325creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019851111_1374creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0014454creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0048614creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0044634creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0065276creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00>q\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019871226_1226creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xac8\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00,X\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019850522_5065creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019530329_1097creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019580409_3656creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019740722_1244creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019651111_4434creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019941023_9983creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00O\xa9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0037831creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00f\x15\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x87q\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00#\x12\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019910521_9074creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00|H\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0084518creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x85@\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x94&\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x89\x18\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xa2J\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x91T\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019910104_2905creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019840527_1903creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xfd!\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0f\x12\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb9.\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0077358creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0075410creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0048880creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00,5\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xad9\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0031730creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0043044creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x0014\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019920329_5666creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019790609_5242creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020000508_4775creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00yc\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0070031creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00[u\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0098684creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0071409creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x87\x16\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xcc\x1a\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0075339creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0094089creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x82_\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9b3\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019560429_5395creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019630419_5308creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0012432creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0025634creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x003#\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0083262creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00Zb\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0032828creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019470213_3747creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00C\xa4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xbb}\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xf6L\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019570212_8143creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0099344creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xcd-\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019460602_8349creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019580902_6482creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0019081creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019631019_8037creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019840611_6879creditscore',
#  b"\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00'\x02\x01\x00\x00\x00\x00\x00creditscore",
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00nZ\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0030113creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019681017_4003creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xbcC\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0056661creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019970913_2947creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028906creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019670314_3035creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00;|\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0018851creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00V!\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0027834creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019770221_5327creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00^\xd5\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0082321creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\r5\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019750411_1267creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00k\x87\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00e\xaf\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019930802_5405creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0062338creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019540528_6678creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019680201_2596creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019900728_7233creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00<\x84\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0056527creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8bm\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019530327_2172creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00QF\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xdc\xdc\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0029045creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0036577creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x003\xd8\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019590213_8141creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019930809_5343creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x80\xe8\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe5\x12\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0038053creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0f\xc6\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xba5\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x05M\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xf9*\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0042376creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0017019creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00:c\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0085387creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x12)\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x001583creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0037367creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0067445creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x12\x1d\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019551003_2314creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00!\xd6\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019721017_3029creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019821017_3196creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019931005_5540creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028563creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0074333creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0071422creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019541014_4458creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x93&\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019790808_6983creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe4t\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00C\xa2\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0080466creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9b\x18\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0062831creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019581217_2402creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0043054creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020000305_5991creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0040157creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0030503creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019610110_1875creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019530723_7364creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019500330_4454creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019800209_7097creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019531222_6407creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019900324_4637creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019740626_8814creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8cN\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0054547creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028364creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0091766creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019800727_2267creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x004281creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019811116_3841creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019800223_7168creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0038042creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019970503_3005creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0044423creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8a\x16\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0048804creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0031030creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019590520_3928creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x07\xf4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019610406_2001creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0038348creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0033849creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0095746creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x14\x13\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0062272creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0015370creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019820604_6306creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0024279creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0093430creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019871001_5063creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019821028_7050creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00<u\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019681114_2022creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xda\xf3\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8cM\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019580106_4453creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019551230_9623creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019870924_3877creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019710409_9932creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x008s\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00J\xac\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0084655creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019790225_9398creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x90G\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0023898creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0031010creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019810323_8399creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0015622creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc3}\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019570510_7906creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x008@\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x80u\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x89E\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xdf\xa6\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0073135creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019660103_6540creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019890522_1114creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8b\xc4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019950320_4344creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0062218creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0fP\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019460929_4570creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0092821creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0048847creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0066024creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019571221_7564creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00"1\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019930608_6739creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019820705_6914creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00a\x7f\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd6\x1b\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00Go\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe8\x1b\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019651006_4249creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0065786creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x92{\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x95\xc4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019850910_2552creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00}\xe3\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0061876creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc6T\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x002054creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0021222creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0079009creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019960920_7375creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019591004_1493creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0073759creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00D=\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x006057creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0040107creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xdd\xdb\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0013452creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x003037creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019950204_9632creditscore',
# ...
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019511029_5507creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0055792creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x008078creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019530420_9881creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019571218_3615creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0053924creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0ct\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019770521_7171creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0018913creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x005\x84\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0089178creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019670125_2853creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019880421_9596creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0074932creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00t\xc7\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00M\x13\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00L\xbb\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xdcr\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0033684creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020010712_3672creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019800224_8736creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0e\xb9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x003224creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0098277creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xa3n\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc0\x94\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00&;\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0046540creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0050590creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019810903_8834creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00e\x16\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019590822_8688creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019490612_5319creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019850629_9351creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019500608_6365creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019970307_6496creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xfbn\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0078362creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0029334creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019970801_5781creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xf1S\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0015027creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb2\x94\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xee\x85\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xfe\xa9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x005~\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019641215_3477creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00v\xe7\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019990509_5517creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00Pb\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0039045creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019550323_1039creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019960108_4229creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019911104_1480creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019990720_3542creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020000809_7872creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00W\xa5\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc0!\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019741007_1077creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0062557creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019941118_9630creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xa91\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019910909_8616creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb6`\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019890714_5320creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00re\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0b\xd5\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0034433creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019710420_8043creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0010921creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019900508_5001creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019780230_2685creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0054733creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0095959creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xc4A\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xea\xda\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019731021_4197creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0092070creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0015490creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0055003creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019790103_4403creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd7+\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019681022_8743creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019970508_3123creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0010605creditscore',
#  b"\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x90'\x00\x00\x00\x00\x00\x00creditscore",
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x003L\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd9t\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0031703creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xdf\xd6\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0035221creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0092581creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019870211_2868creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019730918_6658creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019600526_4808creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd9[\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020000129_9473creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019970301_1634creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb2\x98\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0031824creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00]\x8f\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0081007creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0067570creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019800416_1721creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb1\xb7\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0054944creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xb1-\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019870502_8005creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019980207_8569creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019510609_6193creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028269creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xa7u\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019811009_7513creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0014102creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x0f\x98\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00;\xa8\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0056144creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0097218creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019930214_2834creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019960624_2145creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0032067creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0080021creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019710122_6520creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xbe&\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x8d\x13\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019780630_3374creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020000303_6319creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x002464creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x1d\x06\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0076539creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019680402_4676creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019740808_2210creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe4\xbc\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0029525creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0060622creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019720504_3797creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x06n\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019920813_1856creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0091350creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0055337creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0037187creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xa9o\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019480527_3492creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019820630_3008creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x008\x9e\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019670830_6170creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x9c\xd2\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019450720_9815creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028625creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0078014creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xd9\xe3\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x04\x90\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0032058creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xf8\x9d\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00i\x00\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x02\xb9\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0028628creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019571015_2326creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00e\xbe\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xdb\xad\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0047244creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019570310_8753creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0052565creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00$\xee\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0041046creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019811025_3403creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019711125_5055creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019521210_5680creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0088267creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019650913_1682creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0020010305_8401creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00X\xb4\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019691022_4508creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\xe5\x82\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019610509_4145creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019520318_4695creditscore',
#  b'\x02\x00\x00\x00dob_ssn\x02\x00\x00\x00\r\x00\x00\x0019680121_4164creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x05\x00\x00\x0033905creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x91,\x01\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x003\x94\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x04\x00\x00\x00\x08\x00\x00\x00\x17^\x00\x00\x00\x00\x00\x00creditscore',
#  b'\x02\x00\x00\x00zipcode\x02\x00\x00\x00\x04\x00\x00\x001608creditscore',
#  ...]

# %% [markdown]
# ### Cleanup

# %%
# %cd creditscore/
# !feast teardown
# %cd ..
